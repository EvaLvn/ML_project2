# %%
import pandas as pd
import numpy as np
import nltk 

from lda_helpers import * 
import sys
sys.path.append('../helpers_python')
from pre_processing import *
from helpers import *
# %load_ext autoreload
# %autoreload 2

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Choose the country we want to work with
country = 'France'

# Load data
cleaned_tweets = load_data_lda(country).clean

# %% [markdown]
# ## Params

# %%
# Set the parameters for LDA
params = {
    'vec_repr': {
        'max_df' : 0.95,  # remove all words that appear in more than 95% of the documents
        'min_df' : 1,     # remove all words that appear only once
                },
    'LDA' : {
        'nb_topics' : 9,  # the number of clusters/topics
        'passes': 15,     # number of passes during LDA
        'random_state': 50# seed used 
            }
     }
params['LDA']['alpha'] = 1/params['LDA']['nb_topics'], # the distribution of topics per document paramaters
params['LDA']['beta'] = 1/params['LDA']['nb_topics'],  # the distribution of words per topics parameters

more_stop_words = ['u', 'amp', 'get', 'one', 'go'] # some words we want to remove because they are not interesting

# %% [markdown]
# ### LDA with `gensim.LdaMulticore`

# %% [markdown]
# ## Construct the models

# %%
dictionary = get_dictionary(cleaned_tweets, params, more_stop_words)
corpus = get_corpus_in_bow(cleaned_tweets, dictionary, more_stop_words)

# %% [markdown]
# ## Find best parameters for alpha, betas and number of topics
# ### For the alphas
# The alpha parameter represents the document-topic relation. If alpha is big, every documents will have a lot of topics whereas if it is small each documents would be assigned to only one topic.
#
# In our case, because the documents which are tweets are small, we will make alpha small, so that each tweet is assign to one or two topics at most.
#
# Otherwise we can see that when alpha grows, we have in one topics both communism and black people which we would prefer not to have and have differenciating categories.
#
# ### For the betas
# The beta parameter repesents the topics-word relation. If beta is big, all the topics will have the same distribution over word whereas when it is small the distibution are different and more words in the corpus are taken into account.
#
# For our purpose, because we want to explain the whole data and not only the main topic we have to set beta low i.e. < 0.1
#
# ### For the number of topics
# From the exploratory data analysis, we already saw that there were multiple topics like racist, antisemtism, american elections, covid so we try multiple values expecting that our best topic repartition is around 8.

# %%
alphas = [0.0001, 0.001, 0.01, 0.1, 1, 10]   
betas  = [0.0001, 0.001, 0.01, 0.1, 1, 10]
tune_params(params,corpus, dictionary, alphas = alphas, betas = betas)

# %%
nb_topics = range(3,12,2)
params['LDA']['beta'] = 0.1
params['LDA']['alpha'] = 0.1
tune_params(params,corpus, dictionary, nb_topics=nb_topics)

# %% [markdown]
# ### Topics
# We can give categories we used for labelling to these clusters
# 1. 'tweeter acccounts', 'communism - against bankers , against state  prder '
# 1. 'homophobia'
# 1. 'american elections'
# 1. 'farright', 'Alain Soral', 'communism - against bankers , against state  prder '
# 1. 'white/black - racism', 'women'
# 1. 'jew - antisemtism'
# 1. 'islam', 'terrorism'
# 1. 'immigration'
# 1. Other
#
# Don't have
# - 'India - Pakistan'
# - 'coronavirus - vaccination'
# - 'fantasy sex play'
# - 'homophobia'

# %%
params['LDA']['beta'] = 0.1
params['LDA']['alpha'] = 0.1
params['LDA']['nb_topics'] = 9
model = get_model(params, corpus, dictionary)
show_topics(model)
# Out:
# (0, '0.008*"diversity" + 0.006*"war" + 0.005*"black" + 0.005*"time" + 0.005*"white" + 0.005*"government" + 0.005*"strength" + 0.004*"let"')
# (1, '0.015*"want" + 0.007*"president" + 0.007*"every" + 0.007*"day" + 0.007*"people" + 0.006*"like" + 0.006*"black" + 0.006*"woman"')
# (2, '0.017*"people" + 0.008*"know" + 0.006*"woman" + 0.006*"white" + 0.006*"well" + 0.005*"black" + 0.005*"never" + 0.005*"white_people"')
# (3, '0.010*"racist" + 0.009*"people" + 0.008*"many" + 0.007*"mr" + 0.007*"always" + 0.007*"let" + 0.006*"know" + 0.006*"stop"')
# (4, '0.015*"white" + 0.013*"say" + 0.010*"white_people" + 0.007*"attack" + 0.007*"black" + 0.007*"call" + 0.006*"time" + 0.006*"try"')
# (5, '0.011*"people" + 0.008*"twitter" + 0.006*"like" + 0.006*"today" + 0.005*"america" + 0.005*"face" + 0.004*"day" + 0.004*"friend"')
# (6, '0.007*"hate" + 0.006*"muslim" + 0.005*"know" + 0.005*"medium" + 0.005*"people" + 0.004*"yes" + 0.004*"india" + 0.004*"lie"')
# (7, '0.009*"people" + 0.008*"say" + 0.006*"right" + 0.005*"america" + 0.005*"see" + 0.005*"fight" + 0.005*"germany" + 0.004*"like"')
# (8, '0.011*"biden" + 0.007*"white_people" + 0.006*"islamic" + 0.006*"really" + 0.006*"country" + 0.005*"woman" + 0.005*"make" + 0.004*"first"')

# %%
topics = [
    ['tweeter acccounts', 'communism - against bankers , against state prder'],
    ['homophobia'],
    ['american elections'],
    ['farright', 'Alain Soral', 'communism - against bankers , against state prder'],
    ['white/black - racism', 'women'],
    ['jew - antisemtism'],
    ['islam', 'terrorism'],
    ['immigration'],
    []
]

# %%
# plot topics
data =  pyLDAvis.gensim_models.prepare(model, corpus, dictionary)
pyLDAvis.display(data)

# %% [markdown]
# ## Analysis

# %%
# Get the df with the tweets labelled by hand
df_labels = get_labeled_tweets(country)
# Get the tweets that have been labelled
labeled_tweets = pd.DataFrame(cleaned_tweets[df_labels.index])
# Get the bow representation for these tweets
labeled_tweets['bow'] = get_corpus_in_bow(labeled_tweets['clean'],dictionary)
# Join the two dfs 
df_labels = labeled_tweets.join(df_labels).drop('translated', axis = 1)
df_labels.head(5)

# %%
# Get the most likelly topic 
df_labels['topics'] = df_labels.bow\
            .apply(lambda bow : model.get_document_topics(bow, minimum_probability = 0.3))\
            .apply(lambda tpcs : [topics[t[0]] for t in tpcs][0])
# Compare the topics given by LDA with the ones given by us by giving 1 if the topics are the same
final_score = get_score(df_labels)
print("LDA has an accuracy of %.4f to label the tweets as we did."%(final_score))

# %% [markdown]
# ### Coherence

# %%
documents = pd.DataFrame({"Document": cleaned_tweets,
                              "ID": range(len(cleaned_tweets))})

documents['bow'] = get_corpus_in_bow(documents['Document'],dictionary)
documents['Topic'] = documents.bow.apply(lambda bow : get_topic_from_bow(model, bow))
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
documents_per_topic['Document'] = documents_per_topic['Document'].apply(lambda s : s.split(' '))

# %%
from collections import Counter
texts = documents_per_topic.Document.tolist()
texts = [[t[0] for t in Counter(texts[i]).most_common(10)]for i in range(1,10)]

# %%
cleaned_tweets
# Out:
# 139      muslim commit multiple terrorist attack across...
# 232      toxic upbringing environment anti white hatred...
# 256         nothing allow white white problem need address
# 262      write wall white race slat genocide hyperbole ...
# 265      ficed rothschild return face face reality hyst...
#                                ...
# 22749    hesitate worn bottom people see inside let go ...
# 22751                 india innovative thrust jai swadeshi
# 22767    around world white people get dangerously fed ...
# 22778    fuck petty go year old man weak pathetic creature
# 22785    accord news source suspect detain release name...
# Name: clean, Length: 900, dtype: object

# %%
docs = cleaned_tweets.apply(lambda x: str(x).split()).to_numpy()

# %%
docs
# Out:
# array([list(['muslim', 'commit', 'multiple', 'terrorist', 'attack', 'across', 'europe', 'gt', 'muslim', 'look', 'back', 'anger', 'random']),
#        list(['toxic', 'upbringing', 'environment', 'anti', 'white', 'hatred', 'racism', 'cultivate', 'hollywood', 'medium', 'school', 'un']),
#        list(['nothing', 'allow', 'white', 'white', 'problem', 'need', 'address']),
#        list(['write', 'wall', 'white', 'race', 'slat', 'genocide', 'hyperbole', 'exaggeration']),
#        list(['ficed', 'rothschild', 'return', 'face', 'face', 'reality', 'hysterical', 'assa', 'traor']),
#        list(['refer', 'white', 'people', 'disease', 'probably', 'great', 'way', 'convince', 'u', 'racist', 'go', 'ahead']),
#        list(['one', 'good', 'thing', 'french', 'police', 'never', 'hesitate', 'fire', 'weapon', 'knife', 'wield', 'muslim']),
#        list(['yes', 'af', 'slam', 'merkel', 'import', 'culture', 'hate', 'woman', 'turn', 'berlin', 'baghdad', 'migrant', 'willi']),
#        list(['apart', 'weapon', 'way', 'mamma', 'favorite', 'weapon', 'slipper']),
#        list(['muslim', 'ever', 'respect', 'religious', 'teacher', 'religion', 'koran', 'order', 'religion']),
#        list(['say', 'thousand', 'time', 'bear', 'repeat', 'anti', 'racism', 'dangerous', 'new', 'age', 'religion', 'religi']),
#        list(['post', 'need', 'many', 'many', 'million', 'view', 'share', 'many', 'people']),
#        list(['live', 'age', 'manufacture', 'tragedy', 'tyranny', 'impose', 'upon', 'u', 'result', 'artificial', 'tragedy']),
#        list(['warn', 'communist', 'weaponize', 'fake', 'asian', 'hate', 'crime', 'narrative', 'plot', 'march', 'th', 'u', 'protest', 'party', 'liberation', 'socialis']),
#        list(['think', 'twitter', 'allow', 'certain', 'conservative', 'account', 'maintain', 'follower', 'erase', 'account', 'like', 'min']),
#        list(['america', 'laughingstock']),
#        list(['medium', 'want', 'believe', 'hundred', 'people', 'freedom', 'reclaim']),
#        list(['fuck', 'sake', 'kill', 'two', 'white', 'people', 'death', 'count', 'racism', 'motivation']),
#        list(['help', 'dad', 'attack', 'antifa', 'attack', 'break', 'arm', 'brave', 'dad', 'campaign', 'canada', 'give', 'child', 'drug', 'change']),
#        list(['war', 'wag', 'white', 'people', 'everything', 'fault']),
#        list(['post', 'need', 'many', 'many', 'million', 'view', 'share', 'many', 'people']),
#        list(['every', 'day', 'come', 'onto', 'twitter', 'lose', 'another', 'hundred', 'follower', 'add', 'follower', 'two', 'year']),
#        list(['downfall', 'one', 'kill', 'sadhu', 'insult', 'woman', 'certain', 'parambir', 'singh', 'anil', 'deshmukh', 'uddhav', 'thackeray', 'sanjay', 'raut', 'ht']),
#        list(['panic', 'kitchen', 'rebel', 'restaurateur', 'deprive', 'aid', 'bruno', 'le', 'maire', 'via']),
#        list(['inter', 'n', 'national', 'c', 'chutiya']),
#        list(['left', 'preaches', 'unity', 'heal', 'carry', 'violence', 'denounce', 'violent']),
#        list(['whenever', 'biden', 'speaks', 'know', 'semitic', 'armenoid', 'handler', 'speak', 'instead']),
#        list(['community', 'say', 'black', 'jew', 'operate', 'together', 'coordinate', 'effort', 'dismiss', 'bigotry', 'r']),
#        list(['plan', 'take', 'back', 'hagia', 'sophia']),
#        list(['question', 'point', 'baby', 'wear', 'hijab', 'hijab', 'suppose', 'prevent', 'men', 'tempt', 'sin', 'appea']),
#        list(['play', 'sugarfree', 'fantasy']),
#        list(['white', 'white', 'law', 'protects', 'discriminate', 'white', 'people']),
#        list(['one', 'legally', 'obligate', 'hire', 'people', 'foreign', 'country', 'law', 'tell', 'hire', 'citizen', 'f']),
#        list(['deep']),
#        list(['yes', 'even', 'ruin', 'small', 'humble', 'little', 'farm', 'state', 'like', 'wisconsin', 'live', 'people', 'incom']),
#        list(['play', 'fantasy', 'casanova']),
#        list(['shameful', 'samuel', 'paty', 'style', 'threat', 'head', 'school', 'bow', 'violent', 'jihad', 'mob', 'parent', 'issue', 'apology', 'su']),
#        list(['amaze', 'article', 'people', 'write', 'two', 'year', 'ago', 'show', 'ten', 'thousand', 'follower']),
#        list(['sayer', 'die']),
#        list(['want', 'keep', 'america', 'safe', 'stop', 'import', 'people', 'want', 'kill', 'u', 'simple']),
#        list(['piece', 'bravery', 'alain', 'soral', 'russie', 'toulon']),
#        list(['play', 'luc', 'steeno', 'played', 'accordion']),
#        list(['threat', 'alert', 'terror', 'tie', 'migrant', 'run', 'dangerous', 'mosque', 'amp', 'islamic', 'school', 'florida', 'dr', 'fadi', 'yousef', 'kablawi', 'long', 'history']),
#        list(['sharia', 'uk', 'every', 'woman', 'cover', 'top', 'toe', 'otherwise', 'police', 'collect', 'situati']),
#        list(['chinese', 'corona', 'virus', 'like']),
#        list(['come', 'religious', 'place', 'thief', 'come', 'steal', 'robber']),
#        list(['replace', 'white', 'people', 'white', 'country', 'tell', 'u', 'source', 'st']),
#        list(['fagot', 'take', 'arm']),
#        list(['imagine', 'desperate', 'attention', 'relevancy', 'surgically', 'remove', 'part', 'body']),
#        list(['pay', 'middle', 'eastern', 'terrorist', 'smuggle', 'u', 'via', 'mexican', 'border', 'people', 'sw']),
#        list(['fanart', 'prefer']),
#        list(['still', 'catholic', 'apostate']),
#        list(['turn', 'violent', 'criminal', 'care', 'gun', 'illegal', 'carry']),
#        list(['gayle', 'oprah', 'paid', 'pr', 'harry', 'witch']),
#        list(['make', 'white', 'people', 'happy', 'racist', 'need', 'stop']),
#        list(['wa', 'po', 'typical', 'left', 'wing', 'news', 'organization', 'exists', 'harm', 'conservative', 'jeff', 'bezos', 'u', 'power', 'money']),
#        list(['caught', 'k', 'say', 'true']),
#        list(['afd', 'gottfried', 'curio', 'warn', 'world', 'amp', 'stuns', 'german', 'parliament', 'un', 'amp', 'merkel', 'plan', 'expose', 'make', 'every', 'call', 'refugee']),
#        list(['italy', 'naked', 'jaybird', 'illegal', 'alien', 'muslim', 'invader', 'take', 'leak', 'middle', 'street', 'broad', 'daylight']),
#        list(['hitler', 'nazi', 'war', 'happen', 'racist', 'hat', 'anyone', 'blonde', 'hair', 'amp', 'blue', 'eye']),
#        list(['parliament', 'need', 'time']),
#        list(['many', 'generation', 'american', 'government', 'organize', 'crime', 'syndicate', 'illegal', 'occupation']),
#        list(['unlawful', 'best', 'produce', 'anything', 'beautiful', 'plato']),
#        list(['remove', 'portrait', 'white', 'judge', 'white', 'go', 'ahead', 'tell', 'war']),
#        list(['arbitrariness', 'censorship', 'back', 'west', 'via']),
#        list(['blame', 'anyone', 'know', 'truth', 'adolf', 'hitler', 'amp', 'national', 'socialism', 'victor', 'write', 'history']),
#        list(['actually', 'watch', 'right', 'funny', 'listen', 'black', 'dude', 'talk', 'sell', 'crack']),
#        list(['law', 'enforcement', 'earn', 'every', 'bit', 'hate', 'receive', 'chosen', 'side', 'enemy', 'people']),
#        list(['law', 'enforcement', 'earn', 'every', 'bit', 'hate', 'receive', 'chosen', 'side', 'enemy', 'people']),
#        list(['break', 'new', 'year', 'eve', 'canada', 'police', 'violently', 'raid', 'family', 'gathering', 'six', 'people', 'neighbor', 'report', 'coronavirus']),
#        list(['new', 'year', 'austria', 'civil', 'war', 'like', 'incident', 'amp', 'yell', 'allahu', 'akbar', 'new', 'year', 'eve', 'vienna', 'meanwhile', 'elec']),
#        list(['twitter', 'purge', 'account', 'every', 'single', 'day', 'add', 'follower', 'year', 'instead', 'lose', 'follow']),
#        list(['find', 'ancient', 'statue', 'like', 'sober', 'experience', 'excite', 'one', 'statue', 'represent']),
#        list(['never', 'want', 'equality', 'never', 'want', 'mere', 'empowerment', 'either', 'aim', 'always', 'empow']),
#        list(['delete', 'first', 'one', 'get', 'ratio', 'ed', 'hard', 'uploaded', 'new', 'one', 'allow']),
#        list(['book', 'write']),
#        list(['government', 'enforces', 'hospital', 'put', 'every', 'death', 'covid']),
#        list(['enrichment', 'ireland', 'mob', 'african', 'migrant', 'black', 'life', 'matter', 'communist', 'try', 'attack', 'bus', 'full', 'irish', 'people']),
#        list(['reason', 'white', 'people', 'child', 'simulate', 'experience', 'slave']),
#        list(['try', 'tell', 'everyone', 'year', 'matter', 'nothing', 'good', 'enough', 'crea']),
#        list(['lick', 'foot', 'nigga', 'white', 'trash', 'paris', 'france', 'interracial', 'gay', 'amateur', 'gay']),
#        list(['put', 'account', 'protect', 'mode']),
#        list(['thank', 'australia', 'israel', 'chamber', 'commerce', 'infrastructure', 'showcase', 'great', 'event', 'discus', 'many', 'opportuni']),
#        list(['eu', 'schmuck', 'blast', 'bosnia', 'take', 'well', 'care', 'illegal', 'alien', 'muslim', 'invader', 'burn', 'calle']),
#        list(['play', 'f', 'aschtb', 'nkler', 'partyplanet']),
#        list(['world', 'live', 'world', 'people', 'celebrate', 'turn', 'family', 'member', 'mob']),
#        list(['new', 'follower', 'syria', 'last', 'week', 'see']),
#        list(['replace', 'white', 'people']),
#        list(['expect', 'someone', 'else', 'save', 'expect', 'group', 'save', 'people', 'country']),
#        list(['see', 'episode']),
#        list(['well', 'guy', 'entire', 'continent', 'call', 'sure', 'would', 'great', 'deal', 'easy', 'get']),
#        list(['let', 'perfectly', 'honest', 'left', 'actually', 'care', 'victim', 'mass', 'shooting', 'se']),
#        list(['lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil', 'nigga', 'lil']),
#        list(['play', 'django', 'wagner', 'de', 'muzikant']),
#        list(['philosophy', 'national', 'socialism', 'reawaking', 'mankind', 'consciousness', 'nature', 'importance', 'ra']),
#        list(['philosophy', 'lie', 'national', 'socialism', 'man', 'lie']),
#        list(['whoever', 'control', 'country', 'institution', 'control', 'society', 'perception', 'reality']),
#        list(['people', 'arm', 'security', 'shut', 'hell', 'gun', 'control', 'laughable', 'allow', 'protect', 'themse']),
#        list(['islamic', 'migrant', 'threatens', 'gang', 'rape', 'politician', 'expose', 'illegally', 'operate', 'mosque', 'see', 'video', 'islamic', 'community']),
#        list(['man', 'white', 'supremacist', 'asian', 'hater', 'keep', 'get', 'darker', 'darker']),
#        list(['amount', 'money', 'ever', 'bring', 'equality', 'equality', 'exist', 'anywhere', 'nature', 'brib']),
#        list(['alain', 'soral', 'answer', 'pierre', 'de', 'brague', 'question', 'understand', 'era', 'compensation', 'complacency']),
#        list(['man', 'white', 'supremacist', 'asian', 'hater', 'keep', 'get', 'darker', 'darker']),
#        list(['workout', 'functional', 'real', 'world', 'extend', 'period', 'time']),
#        list(['although', 'one', 'neutral', 'today', 'time', 'everyone', 'inclination', 'towards', 'mine', 'also', 'neutral']),
#        list(['say', 'denounce', 'anti', 'semitism', 'jew', 'say', 'video', 'link']),
#        list(['call', 'domestic', 'terrorism', 'see', 'call', 'terrorism', 'ground', 'political', 'affiliat']),
#        list(['white', 'want', 'something', 'call', 'white', 'supremacy', 'black', 'want', 'thing', 'call', 'response']),
#        list(['law', 'anti', 'white', 'law', 'anti', 'jewish', 'white', 'people', 'really', 'wer']),
#        list(['truth']),
#        list(['necessary', 'win', 'election', 'help', 'someone', 'heart', 'big', 'must', 'heart']),
#        list(['holy', 'place', 'vrindavan', 'cm', 'shri', 'ji', 'hon', 'union', 'jal', 'shakti', 'minister', 'shri', 'water', 'power']),
#        list(['easter', 'australia', 'day', 'allow']),
#        list(['white', 'people', 'ally', 'literally', 'every', 'non', 'white', 'race', 'united']),
#        list(['expose', 'left', 'wing', 'agitator', 'like', 'greta', 'thunberg', 'sacrifice', 'farmer', 'feed', 'global', 'hatred', 'modi', 'thunberg', 'may', 'puppet']),
#        list(['want', 'live', 'around', 'u', 'want', 'live', 'around', 'mutually', 'peacefully', 'separate']),
#        list(['let', 'spell', 'black', 'separatist', 'treat', 'random', 'individual', 'isolated', 'social', 'medium']),
#        list(['great', 'talk', 'common', 'challenge', 'opportunity', 'u', 'congress', 'always', 'bastion', 'su']),
#        list(['black', 'people', 'really', 'little', 'lie', 'small', 'shit']),
#        list(['total', 'utter', 'bullshit']),
#        list(['prove', 'u', 'right', 'every', 'single', 'time']),
#        list(['sister']), list(['dark', 'circle', 'know', 'sign']),
#        list(['trump', 'peace', 'biden', 'war', 'thanks', 'left']),
#        list(['start', 'reimburse', 'ruin', 'fn']),
#        list(['biden', 'need', 'another', 'war', 'middle', 'east', 'also', 'biden', 'proceeds', 'bomb', 'syria']),
#        list(['act', 'spiritual', 'psychological', 'warfare', 'native', 'european', 'people', 'white', 'people', 'nowhere', 'else']),
#        list(['israel', 'law', 'allows', 'authority', 'know', 'identity', 'unvaccinated', 'people']),
#        list(['play', 'jayh', 'nice', 'day']),
#        list(['get', 'ready', 'lady', 'gentleman', 'criminal', 'illegitimate', 'government', 'go', 'wag', 'open', 'war', 'p']),
#        list(['afghanistan', 'saudi', 'arabia', 'dream', 'afternoon', 'b', 'ziers', 'lidl', 'supermarket', 'avenue', 'de', 'badones']),
#        list(['yet', 'bombed', 'middle', 'eastern', 'country']),
#        list(['replace', 'white', 'people']),
#        list(['anti', 'white', 'amp', 'anti', 'american', 'rhetoric', 'exactly', 'taught', 'kid', 'across', 'america']),
#        list(['soral', 'answer', 'episode', 'alain', 'soral', 'family', 'program', 'st', 'phane', 'douard']),
#        list(['average', 'people', 'need', 'start', 'ask', 'okay', 'jew', 'anti', 'white', 'okay', 'white']),
#        list(['communism', 'symptom', 'disease', 'disease', 'look', 'communism', 'come', 'look']),
#        list(['guy', 'charge', 'proud', 'boy', 'name', 'enrique', 'tarrio', 'yet', 'proud', 'boy', 'still', 'label', 'white', 'supre']),
#        list(['semite', 'member', 'people', 'speak', 'spoke', 'semitic', 'language', 'include', 'particular', 'jew']),
#        list(['vaccination', 'blackmail', 'restaurant', 'expect', 'reopen', 'january']),
#        list(['arrogation', 'double', 'entendre', 'via']),
#        list(['terror', 'canada', 'nye', 'amir', 'abdulrahman', 'amp', 'al', 'azan', 'shah', 'muhammad', 'drag', 'police', 'sgt', 'andrew', 'harnett', 'death', 'enrichers']),
#        list(['social', 'medium', 'like', 'densest', 'major', 'city', 'human', 'existence', 'loud', 'chaotic', 'fast', 'pace', 'emotional', 'irr']),
#        list(['allege', 'nurse', 'practitioner', 'threaten', 'deny', 'people', 'treatment', 'political', 'leaning', 'someone', 'sho']),
#        list(['never', 'go', 'solve', 'world', 'problem', 'spread', 'lie', 'hitler', 'germany', 'outlaw', 'firearm', 'ownership']),
#        list(['new', 'normal', 'watchword', 'great', 'reset']),
#        list(['live', 'every', 'stereotype']),
#        list(['call', 'target', 'harassment']),
#        list(['hell', 'holocaust', 'denial', 'illegal', 'place', 'mean', 'illegal', 'simply', 'say', 'something', 'like', 'loo']),
#        list(['assange', 'never', 'gaol', 'expose', 'war', 'crime', 'u', 'government', 'always', 'mystifies']),
#        list(['favor', 'report', 'guy', 'try', 'dox']),
#        list(['year', 'delhi', 'trouble', 'riot', 'delhi', 'ankit', 'rinku', 'sharma', 'kill', 'jihadis', 'delhi']),
#        list(['time', 'school', 'place', 'child', 'could', 'learn', 'safety', 'thanks', 'importation', 'di']),
#        list(['ric', 'dupond', 'moretti', 'act', 'submit', 'zionist', 'lobby', 'via']),
#        list(['break', 'massive', 'cover', 'expose', 'virologist', 'sucharit', 'bhakdi', 'healthy', 'people', 'dangerous', 'vaccine', 'young']),
#        list(['trouble', 'get', 'upset', 'say', 'aaj', 'english']),
#        list(['institutional', 'white', 'genocide', 'look', 'like']),
#        list(['didier', 'raoult', 'must', 'stop', 'war', 'press', 'release', 'say', 'go', 'die']),
#        list(['time', 'people', 'put', 'position', 'power', 'influence', 'base', 'ability', 'base', 'merit']),
#        list(['communism', 'always', 'creates', 'resistance', 'logical', 'response', 'communism', 'always', 'fascism', 'na']),
#        list(['right', 'style', 'commission', 'investigate', 'blm', 'antifa', 'riot', 'torched', 'city', 'su']),
#        list(['quick', 'way', 'get', 'rich', 'america', 'black', 'falsely', 'accuse', 'white', 'person', 'racist', 'toward']),
#        list(['historically', 'whenever', 'marxist', 'bolshevik', 'communist', 'regime', 'take', 'power', 'one', 'first', 'thing']),
#        list(['associate', 'every', 'work', 'r', 'interest', 'country', 'mithun', 'chakraborty']),
#        list(['amaze', 'often', 'jew', 'involve', 'significant', 'world', 'event']),
#        list(['oppose', 'islam', 'racist', 'oppose', 'german', 'national', 'socialism', 'soviet', 'communism', 'nothing', 'w', 'color']),
#        list(['parody', 'account']),
#        list(['trump', 'accomplish', 'last', 'president', 'combine']),
#        list(['trump', 'accomplish', 'last', 'president', 'combine']),
#        list(['covid', 'warn', 'yr', 'old', 'survivor', 'call', 'resistance', 'recur', 'fascism', 'tend', 'hold', 'onto', 'rather', 'magical', 'amp']),
#        list(['true', 'juice', 'extractor', 'gas', 'chamber', 'one', 'step']),
#        list(['three', 'sea', 'rescue', 'ng', 'accuse', 'complicity', 'criminal', 'smuggler']),
#        list(['deny', 'racist', 'actually', 'proof', 'racist']),
#        list(['gt', 'billion', 'covid', 'relief', 'black', 'farmer', 'tell', 'living', 'white', 'supremacist', 'society']),
#        list(['suicidal', 'sweden', 'left', 'wing', 'open', 'border', 'policy', 'blame', 'late', 'allahu', 'akbar', 'attack', 'afghani', 'tamim', 'sultani', 'grant']),
#        list(['event', 'like', 'go', 'continue', 'occur', 'white', 'country', 'citizen', 'form', 'powerful', 'group', 'real', 'li']),
#        list(['deeply', 'disappointed', 'gov', 'abbott', 'proud', 'gab', 'amp', 'jewish', 'support', 'christian', 'run', 'business', 'amp', 'thank']),
#        list(['enrich', 'belgium', 'brussels', 'mohamed', 'mohammed', 'ahmed', 'common', 'name', 'many', 'municipality', 'new', 'stati']),
#        list(['global', 'plot', 'left', 'wing', 'western', 'leader', 'continue', 'open', 'border', 'mass', 'migration', 'imposin']),
#        list(['might', 'audio', 'version', 'concept', 'odysee', 'channel', 'find', 'someone', 'want', 'put', 'together', 'vid']),
#        list(['fraud', 'alert', 'joe', 'biden', 'amp', 'harris', 'resurrect', 'left', 'wing', 'lie', 'call', 'hate', 'crime', 'asian', 'american']),
#        list(['america', 'strange', 'fetish', 'reward', 'idiocy', 'need', 'order', 'become', 'rich', 'famous', 'even', 'get']),
#        list(['guy', 'invent', 'hate', 'crime', 'never', 'happen', 'get', 'free', 'paycheck']),
#        list(['white', 'literally', 'nothing', 'bad', 'could', 'ever', 'accuse', 'racism', 'accuse', 'l']),
#        list(['threatens', 'violence', 'manager', 'video', 'say', 'hope', 'others', 'find', 'beat', 'tri']),
#        list(['voice', 'even', 'low', 'eye', 'level', 'straight', 'neither', 'sign', 'show', 'saxon', 'begin']),
#        list(['uncle', 'mla', 'aunt', 'vice', 'president']),
#        list(['soral', 'answer', 'erfm', 'twenty', 'fourth', 'batch']),
#        list(['morocco', 'muslim', 'youth', 'vandalize', 'brand', 'new', 'casablanca', 'bus', 'apparent', 'reason']),
#        list(['seriously', 'bad', 'news', 'government', 'move', 'piece', 'place', 'carry', 'illegal', 'act']),
#        list(['available', 'preview']),
#        list(['play', 'bobby', 'day', 'rockin', 'robin']),
#        list(['imagine', 'someone', 'snuck', 'punch', 'face', 'behind', 'start', 'kick', 'stomp', 'yo']),
#        list(['stupid', 'fuck', 'bitch']),
#        list(['enrich', 'sweden', 'isi', 'child', 'back', 'sweden', 'pose', 'weapon', 'sever', 'head', 'social', 'service', 'take', 'child', 'fro']),
#        list(['white', 'genocide', 'conspiracy', 'theory', 'need', 'challenge', 'misinformation', 'u', 'experience', 'great']),
#        list(['myth', 'semitic', 'armenoid', 'story']),
#        list(['talk', 'jq', 'day', 'long', 'however', 'people', 'like', 'michael', 'jones', 'catholic', 'even', 'admit', 'whit']),
#        list(['fact', 'liberal', 'consider', 'white', 'guy', 'star', 'athlete', 'change', 'white', 'supremacy', 'tell', 'everythi']),
#        list(['try', 'say', 'jew', 'one', 'lead', 'impeachment']),
#        list(['yes', 'invisible']), list(['disability', 'heval']),
#        list(['everything', 'david', 'hogg', 'reinforces', 'belief', 'one', 'allow', 'vote', 'engage', 'political', 'discours']),
#        list(['try', 'say', 'jew', 'one', 'lead', 'impeachment']),
#        list(['high', 'culture', 'civilization', 'diversity']),
#        list(['see', 'biden', 'openly', 'celebrate', 'white', 'people', 'go', 'extinct', 'america', 'decade', 'really', 'care']),
#        list(['warn', 'parent', 'virginia', 'meet', 'atif', 'qarni', 'secretary', 'education', 'appoint', 'va', 'governor', 'northam', 'qarni', 'born']),
#        list(['well', 'uganda', 'damn', 'well', 'leave', 'sweden']),
#        list(['hungarian', 'prime', 'minister', 'orb', 'n', 'soros', 'population', 'replacement', 'make', 'europe', 'muslim', 'orb', 'n', 'leader', 'pa', 'sto']),
#        list(['demographic', 'jihad', 'swedish', 'government', 'lie', 'massive', 'migration', 'number', 'almost', 'illegal', 'migrant', 'grant', 'citizensh']),
#        list(['spain', 'attack', 'military', 'age', 'migrant', 'infect', 'coronavirus', 'storm', 'border', 'fence', 'socialist', 'gov', 'caught', 'distri']),
#        list(['remember', 'allow', 'even', 'much', 'question', 'woman', 'story', 'story', 'holocaust', 'told']),
#        list(['beating', 'u', 'game', 'shut', 'game', 'fucker', 'literally', 'take', 'ball', 'g']),
#        list(['enrichment', 'father', 'beat', 'sexually', 'abuse', 'daughter', 'check', 'muslim', 'sweden', 'refuse', 'deport', 'court', 'h']),
#        list(['remember', 'nato', 'bombing', 'yugoslavia']),
#        list(['see', 'work', 'literally', 'anything', 'infringes', 'money', 'power', 'decry', 'white']),
#        list(['lot', 'picture', 'show', 'holodomor', 'gulag', 'mostly', 'white', 'folk']),
#        list(['turkish', 'president', 'recep', 'tayyip', 'erdogan', 'file', 'criminal', 'complaint', 'dutch', 'opposition', 'leader', 'geert', 'wilder']),
#        list(['join', 'corona', 'cult', 'today', 'tire', 'people', 'still', 'enjoy', 'life', 'exactly', 'right', 'thing', 'cont']),
#        list(['illustrate', 'little', 'government', 'care', 'people', 'nothing']),
#        list(['sharia', 'sweden', 'conservative', 'journalist', 'ingrid', 'carlqvist', 'amp', 'maria', 'celander', 'indict', 'thought', 'crime', 'islam', 'face']),
#        list(['biden', 'amp', 'eu', 'join', 'force', 'eu', 'commissioner', 'ylva', 'johansson', 'see', 'video', 'work', 'biden', 'fight', 'right', 'wing', 'extremist']),
#        list(['fbi', 'arrest', 'doug', 'mackey', 'aka', 'ricky', 'vaughn', 'conservative', 'journalist', 'florida', 'face', 'year', 'hurt', 'democrat']),
#        list(['globalists', 'celebrate', 'eu', 'biden', 'join', 'force', 'fight', 'right', 'wing', 'extremist', 'islamize', 'west', 'ban', 'free', 'speech', 'islamic']),
#        list(['hamas', 'link', 'cair', 'amp', 'soros', 'unite', 'push', 'blasphemy', 'law', 'wan', 'america', 'cair', 'call', 'legislator', 'label', 'criticism']),
#        list(['white', 'supremacy', 'mean', 'white', 'people', 'believe', 'white', 'life', 'matter', 'war', 'wag', 'agai']),
#        list(['australian', 'student', 'year', 'behind', 'average', 'chinese', 'student', 'sat', 'test', 'year', 'behind']),
#        list(['alert', 'communist', 'senator', 'chris', 'murphy', 'connecticut', 'national', 'security', 'threat', 'murphy', 'infiltrate', 'senate', 'fo']),
#        list(['soral', 'answer', 'episode', 'alexandre', 'langlois']),
#        list(['jake', 'tapper', 'dnc', 'operative', 'expose', 'wikileaks', 'left', 'wing', 'hack', 'nerve', 'say', 'kaleigh', 'mc', 'ne']),
#        list(['collect', 'coin', 'like', 'jew', 'anti', 'semitic', 'humor', 'slippage', 'elect', 'official', 'sarcelles', 'see']),
#        list(['war', 'adolf', 'hitler', 'never', 'end', 'evolve', 'war', 'white', 'people']),
#        list(['new', 'year', 'eve', 'wuhan', 'v', 'nyc', 'spot', 'communist', 'nation']),
#        list(['freedom', 'gift', 'beyond', 'estimate', 'give', 'god', 'nation', 'perseverance', 'courage', 'consistency']),
#        list(['savitri', 'devi', 'write', 'numerous', 'time', 'determine', 'quality', 'person', 'people', 'view']),
#        list(['coronavirus', 'tyranny', 'truth', 'teller', 'arrest', 'uk', 'woman', 'arrest', 'film', 'inside', 'empty', 'hospital', 'post', 'online']),
#        list(['course', 'american', 'medium', 'never', 'show', 'capital', 'city', 'european', 'union', 'new', 'year', 'eve', 'bruss']),
#        list(['basically', 'say', 'long', 'racism', 'direct', 'toward', 'white', 'people', 'white', 'country']),
#        list(['muslim', 'mayor', 'london', 'fire', 'new', 'year', 'eve', 'firework', 'display', 'feature', 'black', 'life', 'matter', 'marxist', 'clenched']),
#        list(['folkish', 'state', 'make', 'certain', 'suitable', 'education', 'youth', 'day', 'obtain', 'race', 'ripe']),
#        list(['guarantee', 'chick', 'like', 'anything', 'luxury']),
#        list(['shill', 'foreign', 'domestic', 'enemy']),
#        list(['accusatory', 'inversion', 'modus', 'operandi']),
#        list(['marxism', 'virus', 'mutates', 'spread', 'host', 'host', 'time', 'bolshevism', 'communism', 'social', 'democracy']),
#        list(['literally', 'every', 'single', 'time', 'hear', 'someone', 'spray', 'paint', 'swastika', 'synagogue', 'end', 'hoax', 'lit']),
#        list(['never', 'want', 'equality', 'always', 'secretly', 'want', 'revenge']),
#        list(['islamic', 'pakistan', 'medium', 'blackout', 'muslim', 'destroy', 'another', 'hindu', 'temple', 'pakistan', 'modi', 'caa', 'give', 'citizenship', 'persecute']),
#        list(['equality', 'liberal', 'construct']),
#        list(['good', 'pornography', 'toxic', 'legally', 'allow', 'exist']),
#        list(['true', 'black', 'woman', 'africa', 'landmass', 'black', 'overwhelm', 'super', 'majority']),
#        list(['anyone', 'know', 'ratio', 'jew', 'ce', 'major', 'american', 'corporation']),
#        list(['march', 'nyc', 'mayor', 'de', 'blasio', 'msnbc', 'amp', 'healthy', 'n', 'yers', 'little', 'th']),
#        list(['every', 'non', 'white', 'race', 'planet', 'encourage', 'celebrate', 'history', 'heritage', 'culture', 'white', 'race']),
#        list(['migrant', 'party', 'taxpayer', 'fund', 'resort', 'pool', 'spain', 'remains', 'lockdown', 'two', 'week', 'ago', 'migrant', 'left', 'wing', 'red']),
#        list(['lady', 'question', 'imagine', 'pill', 'men', 'begin', 'market', 'would', 'really', 'trust']),
#        list(['friend', 'waffen', 'veteran', 'wiking', 'division', 'swore', 'cold', 'ext']),
#        list(['america', 'pay', 'attention', 'coordinate', 'global', 'attack', 'india', 'left', 'radical', 'launch', 'campaign', 'destr']),
#        list(['anyone', 'know', 'ratio', 'jew', 'ce', 'major', 'american', 'corporation']),
#        list(['people', 'want', 'walk', 'car', 'well', 'illusion', 'remain', 'anyway', 'good', 'morning', 'thursday', 'thought']),
#        list(['democrat', 'rep', 'jackie', 'speier', 'think', 'lot', 'white', 'american', 'u', 'military', 'national', 'security', 'threat']),
#        list(['fifteen', 'girl', 'saudi', 'arabia', 'burn', 'alive', 'islamic', 'sharia', 'religious', 'police', 'let', 'leave', 'burning']),
#        list(['brittany', 'huge', 'slut']),
#        list(['friend', 'india', 'please', 'contact', 'help', 'expose', 'left', 'coordinate', 'attack', 'country', 'indian', 'fa']),
#        list(['basically', 'illegal', 'immigrant', 'get', 'citizenship', 'replace', 'u', 'either', 'way', 'cool', 'steven', 'repeat']),
#        list(['like', 'cold', 'cold', 'make', 'white', 'ancestor', 'hard', 'strong', 'broke', 'weak', 'bloodline', 'ensure']),
#        list(['austrian', 'girl', 'told', 'wear', 'hijab', 'prevent', 'assault', 'migrant', 'fmr', 'member', 'parliament', 'suggests', 'austrian', 'born', 'girl']),
#        list(['white', 'privilege', 'actually', 'exist', 'listen', 'mindless', 'robot', 'drone', 'repeat']),
#        list(['germany', 'stab', 'spree', 'frankfurt', 'leaf', 'several', 'injured', 'german', 'authority', 'probe', 'attacker', 'motif']),
#        list(['whine', 'tv', 'artist', 'lend', 'voice', 'family', 'victim']),
#        list(['kill', 'kill', 'war', 'police', 'france', 'mainly', 'african', 'arab', 'muslim', 'commu']),
#        list(['know', 'many', 'people', 'receive', 'permanent', 'ban', 'social', 'medium', 'account', 'express', 'concern', 'drag']),
#        list(['belgium', 'first', 'islamic', 'state', 'europe', 'one', 'third', 'country', 'population', 'foreign', 'origin', 'brussels', 'belg']),
#        list(['suck', 'whitedick', 'nigger', 'gayraceplay', 'gaysex', 'oral', 'gayoral', 'interracialgaysex', 'blacksucker', 'bwc']),
#        list(['encourage', 'people', 'call', 'attitude', 'like', 'attitude', 'could', 'get', 'arrest', 'sentence']),
#        list(['gt', 'white', 'supremacy', 'virus', 'like', 'virus', 'die', 'body', 'left', 'infect', 'w']),
#        list(['new', 'gab', 'post', 'east', 'west', 'divide', 'read', 'way']),
#        list(['bioterrorism', 'bangladeshi', 'muslim', 'doctor', 'arrest', 'boston', 'try', 'obtain', 'deadly', 'ricin', 'fbi', 'investigate', 'dr', 'ishtiaq']),
#        list(['putin', 'responds', 'biden', 'threat', 'wish', 'good', 'health']),
#        list(['rahul', 'gandhi', 'big', 'asset', 'bjp']),
#        list(['repeat', 'white', 'get', 'dictate', 'white', 'people', 'anti', 'white', 'raci']),
#        list(['muslim', 'natural', 'ally', 'race', 'sourc']),
#        list(['literally', 'neither', 'men', 'kill', 'white', 'people', 'let', 'alone', 'white', 'nationalist', 'kill', 'black']),
#        list(['expose', 'covid', 'lockdown', 'rule', 'apply', 'salvini', 'left', 'wing', 'italian', 'trial', 'judge', 'salvini', 'trial', 'kidnapping', 'w']),
#        list(['shock', 'video', 'famous', 'journalist', 'expose', 'suicidal', 'effect', 'sweden', 'open', 'border', 'policy', 'swede', 'told']),
#        list(['strength', 'ancestor', 'life', 'within', 'blood', 'strength', 'survive', 'long', 'enough', 'conti']),
#        list(['true', 'never', 'forget']),
#        list(['censorship', 'laughable', 'pathetic', 'scar', 'conservative']),
#        list(['get', 'align', 'hebrew', 'mythology', 'story']),
#        list(['final', 'round', 'shivgaan', 'competition', 'full', 'swing', 'across', 'maharashtra', 'eve', 'chhatrapati', 'shivaji', 'maharaj', 'birth', 'anniversary', 'umbrella']),
#        list(['france', 'sudanese', 'muslim', 'illegal', 'alien', 'stab', 'immigration', 'official', 'death', 'asylum', 'claim', 'reject']),
#        list(['heartbreaking']),
#        list(['mdrrrr', 'see', 'pair', 'look', 'like', 'clutch', 'pedal']),
#        list(['power']),
#        list(['must', 'watch', 'arizona', 'parent', 'fight', 'back', 'school', 'board', 'communist', 'anti', 'racism', 'initiative', 'child', 'indoctrin']),
#        list(['asks', 'compromise', 'always', 'include', 'give', 'right', 'gain', 'control', 'refer', 'democr']),
#        list(['left', 'furious', 'brandon', 'elliot', 'white', 'supremacist', 'instead', 'lifetime', 'parole', 'murder', 'mother', 'sai']),
#        list(['berry', 'case', 'jeane', 'manson', 'accuse', 'member', 'pedophile', 'sect', 'coline', 'berry', 'via']),
#        list(['wave', 'illegal', 'alien', 'clearly', 'fund', 'believe', 'really', 'bought', 'shirt', 'th']),
#        list(['injury', 'today', 'insurrection', 'oh', 'wait', 'mean', 'medium', 'full', 'crap']),
#        list(['weak', 'argument', 'difference', 'white', 'kid', 'already', 'die', 'fentanyl', 'overdose', 'l']),
#        list(['happens', 'white', 'become', 'minority']),
#        list(['france', 'muslim', 'arrest', 'try', 'carry', 'attack', 'jewish', 'school', 'amp', 'kosher', 'grocery', 'video', 'prosecutor', 'cry', 'mental', 'illness']),
#        list(['medium', 'try', 'get', 'black', 'murder', 'innocent', 'white', 'people', 'white', 'people', 'fully', 'prepared', 'defend', 'yourselv']),
#        list(['people', 'ready', 'admit', 'yet', 'real', 'war', 'wag', 'white', 'people']),
#        list(['everybody', 'want', 'believe', 'secret', 'underground', 'army', 'organization', 'go', 'fix', 'everything']),
#        list(['nigga', 'like', 'life', 'anime', 'yea', 'bro', 'one', 'piece', 'shit']),
#        list(['biden', 'let', 'million', 'illegals', 'america', 'vaccination', 'record', 'democrat']),
#        list(['thank', 'advertising']),
#        list(['terrorist', 'come', 'terrorist', 'come']),
#        list(['governor', 'denounce', 'democrat', 'run', 'twitter', 'allows', 'left', 'attack', 'jewish', 'sile']),
#        list(['case', 'prima', 'facie', 'seem', 'fault', 'delivery', 'boy', 'kamaraj', 'hitesha', 'pull', 'whole']),
#        list(['trans', 'child', 'like', 'vegan', 'dog', 'know', 'chose']),
#        list(['play', 'various', 'artist', 'fanfare', 'hunger', 'thirst']),
#        list(['power', 'go', 'force', 'individual', 'citizen', 'comply', 'average', 'citizen', 'know']),
#        list(['ally', 'people', 'white', 'people', 'always', 'always', 'stop']),
#        list(['win', 'seat', 'georgia', 'mitt', 'romney', 'go', 'officially', 'declare', 'democrat', 'good', 'riddance']),
#        list(['long', 'machine', 'shut', 'georgia', 'night']),
#        list(['clarkston', 'georgia', 'one', 'georgia', 'large', 'mosque', 'built', 'small', 'city', 'clarkston', 'resident']),
#        list(['get', 'teary', 'eyed', 'see', 'elderly', 'veteran', 'show', 'freedom', 'plaza', 'fight', 'trump', 'incredible', 'co']),
#        list(['suicidal', 'socialist', 'spain', 'moroccan', 'migrant', 'mohamed', 'professional', 'robber', 'commit', 'crime', 'h']),
#        list(['warn', 'u', 'democratic', 'party', 'copy', 'germany', 'deploys', 'antifa', 'stormtroopers', 'conservative', 'germany', 'left', 'wing', 'gov']),
#        list(['abolish', 'whiteness', 'mean', 'abolish', 'white', 'people', 'fact', 'popular', 'well', 'receive', 'slogan']),
#        list(['patriot', 'fight', 'back', 'san', 'diego', 'gym', 'owner', 'sue', 'state', 'amp', 'county', 'official', 'tyrannical', 'lockdown', 'measure', 'wa']),
#        list(['happen', 'look', 'like', 'suitcase', 'democrat', 'ballot', 'show']),
#        list(['vote', 'ossoff', 'would', 'need', 'remain', 'vote', 'win']),
#        list(['quite', 'simply', 'interest', 'le']),
#        list(['time', 'see', 'mike', 'penny', 'truly', 'patriot']),
#        list(['already', 'election', 'need', 'mike', 'penny', 'stop', 'democrat', 'steal']),
#        list(['arrest', 'people', 'fraudulently', 'get', 'child', 'college', 'however', 'even', 'investigate', 'official', 'fraudulent']),
#        list(['many', 'vote', 'discover', 'georgia', 'tonight', 'watch', 'suitcase', 'ga', 'sen']),
#        list(['read', 'two', 'new', 'openly', 'anti', 'illegal', 'migrant', 'pro', 'border', 'minister', 'appoint', 'conservative', 'prime', 'minister', 'kyriakos']),
#        list(['back', 'another', 'twitter', 'ban', 'new', 'crime', 'quote', 'world', 'health', 'organization', 'discus', 'new', 'vaccination']),
#        list(['go', 'forward', 'twitter', 'tweet', 'mention', 'coronavirus', 'vaccination', 'censor', 'twitter', 'part']),
#        list(['nation', 'yahweh', 'mayor', 'miami', 'xavier', 'su', 'rez', 'declare', 'yahweh', 'ben', 'yahweh', 'day', 'october', 'mon']),
#        list(['shame', 'gop', 'ballot', 'atlanta', 'start', 'come', 'even', 'though', 'poll', 'close', 'five', 'hour', 'ago', 'democrat', 'co']),
#        list(['homosexual', 'find', 'criticize', 'heteros', 'much', 'without', 'u', 'even', 'exist']),
#        list(['break', 'sweden', 'admits', 'people', 'die', 'high', 'rate', 'due', 'pandemic', 'video', 'statistic', 'reveal', 'overall', 'death', 'rate']),
#        list(['anti', 'hitler', 'sentiment', 'reach', 'fanatical', 'insanity', 'le', 'severity', 'religious', 'hysteria', 'anyone', 'stoop']),
#        list(['hysteria', 'freak', 'see', 'hitler', 'literally', 'everywhere', 'go', 'continue', 'affirm', 'say', 'fo']),
#        list(['know', 'many', 'purge', 'account', 'able', 'survive', 'account', 'survive', 'night']),
#        list(['enough', 'people', 'drop', 'look']),
#        list(['flag', 'ny', 'dems', 'let', 'let', 'one', 'credible', 'scandal', 'distract', 'another', 'credible', 'disa']),
#        list(['guy', 'tune', 'est', 'click', 'link', 'see', 'donald', 'trump', 'cpac', 'address', 'cpac', 'general']),
#        list(['democrat', 'work', 'harder', 'rebuild', 'c', 'swamp', 'american', 'job']),
#        list(['trump', 'present', 'future', 'republican', 'party', 'plan', 'run']),
#        list(['cosmetic', 'industry', 'perfumery', 'trade', 'also', 'see', 'existence', 'danger', 'open', 'letter', 'appeal']),
#        list(['threat', 'alert', 'radical', 'communist', 'tie', 'nominate', 'secretary', 'interior', 'deb', 'haaland', 'nomination', 'completel']),
#        list(['thought', 'hillary', 'aka', 'schrillary', 'clinton', 'new', 'book', 'welcome']),
#        list(['racist', 'cookie', 'lecture', 'u', 'wokeness']),
#        list(['didnt', 'happen', 'would', 'b', 'funny']),
#        list(['translation', 'many', 'white', 'people', 'science', 'statistic', 'technology', 'go', 'replace', 'white']),
#        list(['anyone', 'good', 'explanation', 'china', 'allow', 'access', 'u', 'power', 'grid', 'hell']),
#        list(['nikol', 'pashinyan', 'prime', 'minister', 'armenia', 'confesses', 'occupation', 'percent', 'shusha', 'populati']),
#        list(['dead', 'boris', 'johnson', 'say', 'everything', 'could', 'political', 'epitaph', 'indolent', 'prime', 'minister']),
#        list(['hindu', 'le', 'sikh', 'today', 'e', 'hoist', 'flag', 'religion', 'red', 'fort']),
#        list(['people', 'still', 'oblivious', 'truth', 'right', 'plain', 'sight']),
#        list(['diversity', 'sensitivity', 'training', 'really', 'mean', 'anti', 'white', 'indoctrination', 'critical', 'race', 'theory']),
#        list(['people', 'still', 'oblivious', 'truth', 'right', 'plain', 'sight']),
#        list(['rail', 'go', 'work']),
#        list(['men', 'pig', 'u', 'stop', 'living', 'stop', 'filth', 'serious']),
#        list(['even', 'issue', 'black', 'asian', 'racism', 'violence', 'narrative', 'remains', 'white', 'people', 'real', 'pro']),
#        list(['terrorist', 'attack', 'india', 'islamic', 'mob', 'drag', 'hindu', 'rinku', 'sharma', 'home', 'slaughter', 'front', 'parent', 'wh']),
#        list(['army', 'illegal', 'migrant', 'invade', 'hungarian', 'home', 'mayor', 'demand', 'military', 'action', 'woman', 'found', 'army', 'illegals']),
#        list(['ego', 'always', 'ruin', 'man', 'one', 'vision', 'clearest', 'lens']),
#        list(['blackwashing', 'white', 'history', 'continue', 'force', 'stop']),
#        list(['black', 'need', 'liberal', 'woman', 'offend', 'behalf', 'even', 'think', 'liberal', 'really', 'offend', 'anywa']),
#        list(['right', 'guy', 'trial', 'face', 'ten', 'year', 'prison', 'meme', 'another', 'guy', 'give', 'year', 'sent']),
#        list(['nothing', 'civil', 'politics', 'anymore', 'politics', 'war', 'either', 'accept', 'prepare', 'accordingly']),
#        list(['one', 'trump', 'lawyer', 'play', 'unedited', 'fine', 'people', 'hoax', 'video', 'debunk', 'front', 'america', 'network']),
#        list(['friend', 'india', 'website', 'story', 'rinku', 'sharma', 'block', 'twitter', 'however', 'continue']),
#        list(['well', 'really', 'want', 'get', 'subject', 'serial', 'killer', 'start', 'samuel', 'little']),
#        list(['struggle', 'real', 'god', 'nowhere', 'bible', 'say', 'worry', 'stress', 'amp']),
#        list(['female', 'palestinian', 'muslim', 'terrorist', 'say', 'prepare', 'carry', 'suicide', 'bombing', 'mission', 'jew', 'like', 'prep']),
#        list(['blackwashing', 'white', 'history', 'continue', 'force', 'stop']),
#        list(['new', 'gab', 'post', 'burn', 'coal', 'pay', 'toll', 'meme']),
#        list(['get', 'ro', 'pfp', 'would', 'sit', 'one', 'bestie']),
#        list(['people', 'fake', 'hate', 'crime', 'free', 'government', 'money']),
#        list(['way', 'win', 'socio', 'political', 'fight', 'attract', 'fighter', 'side', 'pro', 'white', 'community', 'need', 'foc']),
#        list(['plz', 'support', 'student', 'amp', 'part', 'campaign']),
#        list(['innovation', 'molasses', 'possible', 'clamp', 'liquor']),
#        list(['dude', 'fuck', 'robot']),
#        list(['nothing', 'see', 'folk', 'diversity', 'continue', 'great', 'strength']),
#        list(['play', 'wolter', 'kroes', 'viva', 'hollandia']),
#        list(['blame', 'white', 'people', 'violent', 'crime', 'commit', 'black', 'end', 'piss', 'entire', 'wh']),
#        list(['house', 'democrat', 'push', 'cable', 'company', 'big', 'tech', 'get', 'rid', 'conservative', 'news', 'network']),
#        list(['londonistan', 'tesco', 'worker', 'help', 'police', 'take', 'muslim', 'attacker', 'brandishing', 'multiple', 'knife']),
#        list(['sorry', 'break', 'bimbo', 'every', 'guy', 'planet', 'want', 'sleep']),
#        list(['crack', 'smoking', 'hunter', 'biden', 'cry', 'racism', 'deflect', 'swedish', 'sex', 'scandal', 'hunter', 'smear', 'come', 'swedish', 'authorit']),
#        list(['today', 'first', 'day', 'zero', 'degree', 'entire', 'hour']),
#        list(['identity', 'generation', 'techouva', 'anti', 'semitism', 'anti', 'zionism', 'place', 'u']),
#        list(['gt', 'replaces', 'white', 'men', 'normalize', 'concept', 'white', 'people', 'replace', 'non', 'white', 'white']),
#        list(['look', 'like', 'everything', 'prove', 'hitler', 'right']),
#        list(['say', 'keep', 'right', 'say', 'one', 'single', 'white', 'man', 'alive', 'today', 'ever', 'slave']),
#        list(['hunt', 'white', 'supremacist', 'era', 'witch', 'hunt', 'new', 'regime', 'want', 'look', 'every', 'white', 'person', 'w']),
#        list(['race', 'alain', 'soral', 'fr', 'jus', 'may']),
#        list(['really', 'modi', 'ji', 'get', 'credit', 'rejuvenation', 'include', 'go', 'journey', 'become', 'possible']),
#        list(['manage']), list(['never', 'forget']),
#        list(['warn', 'left', 'wing', 'fight', 'morph', 'pandemic', 'lockdown', 'climate', 'lockdown', 'climate', 'lockdown', 'private', 'vehicle', 'use', 'b']),
#        list(['much', 'bad', 'everything', 'try', 'pretend', 'trump']),
#        list(['tell', 'u', 'else', 'could', 'seem', 'may', 'side', 'effect']),
#        list(['time', 'fix', 'mukhtar', 'ansari', 'salwar', 'peeli']),
#        list(['follow', 'france', 'footstep', 'austria', 'begin', 'crackdown', 'muslim']),
#        list(['america', 'literally', 'white', 'people', 'single', 'western', 'country', 'planet', 'anti', 'american', 'e']),
#        list(['biden', 'test', 'illegal', 'alien', 'coronavirus', 'le', 'month', 'biden', 'number', 'people', 'illegally']),
#        list(['queer', 'activist', 'hit', 'woman', 'come', 'shout', 'revolt', 'system', 'prostitution', 'ra']),
#        list(['daily', 'reminder', 'real', 'time', 'choreograph', 'synchronize', 'dance', 'routine', 'office', 'hou']),
#        list(['easy', 'meat', 'another', 'fail', 'muslim', 'asylum', 'seeker', 'rape', 'murder', 'chop', 'body', 'british', 'woman', 'lure']),
#        list(['gt', 'little', 'girl', 'also', 'kinky', 'someone', 'explain', 'part', 'campaign', 'normalize', 'idea']),
#        list(['biden', 'obama', 'back', 'terrorist', 'please', 'islamic', 'pakistani', 'sharia', 'court', 'overturn', 'conviction']),
#        list(['literally', 'zero', 'justification', 'flood', 'white', 'country', 'non', 'white', 'foreigner', 'whole', 'age', 'dy']),
#        list(['radical', 'somali', 'congressmuslim', 'ilhan', 'omar', 'mn', 'threatens', 'force', 'republican', 'congresswoman', 'office']),
#        list(['course', 'even', 'let', 'white', 'one', 'thing', 'non', 'white', 'ob', 'acce']),
#        list(['people', 'celebrate', 'genocide', 'social', 'medium', 'platform', 'allow', 'yet', 'told', 'live', 'wh']),
#        list(['lgbt', 'deviant', 'disrespect', 'kaaba', 'bo', 'azi', 'university', 'detain']),
#        list(['want', 'know', 'exactly', 'many', 'firearm', 'exactly', 'many', 'round', 'ammunition']),
#        list(['enrich', 'uk', 'refugee', 'demand', 'hotel', 'set', 'fire', 'barrack', 'threaten', 'kidnapping', 'staff', 'commonplace', 'europ']),
#        list(['firearm', 'registration', 'always', 'lead', 'firearm', 'confiscation', 'always', 'without', 'exception', 'need', 'contact']),
#        list(['yet', 'another', 'evil', 'white', 'man', 'save', 'helpless', 'animal', 'almost', 'behavior', 'genetic', 'something']),
#        list(['buy', 'story', 'second', 'pipe', 'bomb', 'really', 'plant', 'dc', 'capitol', 'guarantee']),
#        list(['inca', 'people', 'conquer', 'genocided', 'killke', 'people', 'another', 'south', 'american', 'tribe', 'big', 'deal', 'b']),
#        list(['tik', 'tok', 'innocent', 'social', 'network', 'indian', 'redneck', 'year', 'old', 'quiet', 'fun']),
#        list(['flashback', 'fbi', 'take', 'poster', 'seek', 'islamic', 'terrorist', 'hamas', 'link', 'cair', 'complain', 'show', 'photo', 'fb']),
#        list(['never', 'entirely', 'comfortable', 'truth', 'behind', 'champion', 'always', 'fight', 'something', 'otherwi']),
#        list(['repeat', 'lie', 'truth', 'know', 'want', 'erase', 'white', 'history']),
#        list(['john', 'kohn', 'aka', 'john', 'kerry', 'claim', 'earth', 'nine', 'year']),
#        list(['anyway', 'would', 'never', 'stop', 'repeat', 'place', 'woman', 'tiktok', 'quite', 'simply']),
#        list(['time', 'social', 'medium', 'limited', 'use', 'time', 'wisely', 'anti', 'white', 'take', 'war', 'white', 'ser']),
#        list(['hat', 'white', 'people', 'era', 'late', 'great', 'pop', 'culture', 'cool', 'fashion', 'trend']),
#        list(['ptdrrrr', 'nintendo', 'schwitz']),
#        list(['fund', 'dedication', 'shri', 'ram', 'mandir', 'zomato', 'pizza', 'hut', 'domino', 'swiggy', 'mango', 'shopkeeper']),
#        list(['harassment', 'violence', 'impersonation', 'zionism', 'ulcan', 'trial', 'via']),
#        list(['almost', 'every', 'day', 'quietly', 'think', 'amerindian', 'actually', 'choice', 'fight', 'openly']),
#        list(['current', 'swallower']),
#        list(['conquer', 'illegal', 'minor', 'brought', 'dallas', 'male', 'age']),
#        list(['multi', 'racial', 'society', 'create', 'peace', 'prosperity', 'people', 'create', 'animosity', 'hostility', 'hatred', 'vi']),
#        list(['black', 'woman', 'move', 'white', 'neighborhood', 'complains', 'many']),
#        list(['openly', 'admit', 'displace', 'white', 'people', 'white', 'place', 'living', 'white', 'supremacist', 'conspirac']),
#        list(['exactly', 'think', 'culture', 'come', 'think', 'magically', 'fall', 'sky', 'arbitrarily']),
#        list(['even', 'black', 'want', 'segregation', 'back', 'peaceful', 'separation', 'solution', 'today', 'catastrophic', 'failure', 'race', 'r']),
#        list(['firstly', 'thousand', 'people', 'hundred', 'nice', 'gaslighting', 'sky', 'news', 'usual', 'secondly', 'cop']),
#        list(['look', 'accept', 'random', 'cop', 'beating', 'people', 'baton', 'like', 'use', 'one', 'call']),
#        list(['treat', 'big', 'deal', 'rioter', 'antifa', 'whatever', 'reason', 'police', 'always', 'se']),
#        list(['one', 'one']),
#        list(['germany', 'threatens', 'citizen', 'merkel', 'release', 'ultimatum', 'get', 'vaccinate', 'banish', 'germany', 'already', 'throw', 'quarantine']),
#        list(['yes', 'true', 'leftist', 'lot', 'common', 'nazi']),
#        list(['many', 'innocent', 'white', 'child', 'die', 'start', 'storm', 'street', 'righteous', 'hatred']),
#        list(['right', 'replace', 'white', 'man', 'twenty', 'dollar', 'bill', 'black', 'woman', 'worthy', 'high', 'priority']),
#        list(['lol', 'say', 'republican', 'today', 'like', 'jewish', 'holocaust', 'apparently']),
#        list(['german', 'try', 'warn', 'u']),
#        list(['city', 'burn', 'ransack', 'violent', 'terrorist', 'savage', 'summer', 'long', 'give', 'fuck', 'le', 'th']),
#        list(['white', 'people', 'get', 'dangerously', 'fed', 'foreigner', 'get', 'away', 'countless', 'act', 'violence']),
#        list(['love', 'george', 'monbiot', 'pummel', 'andrew', 'bowie', 'monbiot', 'absolutely', 'cool', 'measure', 'logical', 'bowie', 'typic']),
#        list(['brexit', 'cost', 'uk', 'gdp', 'first', 'year', 'body', 'blow', 'uk', 'economy', 'plummet', 'almost', 'cer']),
# ...
#        list(['diversity', 'safe', 'neighborhood']),
#        list(['anyone', 'think', 'create', 'video', 'channel', 'want', 'deal', 'tube', 'censorship', 'bit', 'chute', 'shitty']),
#        list(['say', 'year', 'ago', 'lot', 'people', 'say', 'hyperbolic']),
#        list(['want', 'really', 'think', 'white', 'man', 'every', 'dollar', 'government', 'take', 'give', 'black']),
#        list(['always', 'little', 'shit', 'think', 'smarter', 'elder', 'inevitably', 'end', 'shit']),
#        list(['get', 'ready', 'white', 'people', 'joe', 'biden', 'america', 'inbound', 'gt', 'unrelenting', 'stream', 'immigration', 'non', 'stop', 'gt']),
#        list(['politician', 'marine', 'le', 'pen', 'party', 'france', 'slam', 'famous', 'ballet', 'du', 'nord', 'put', 'woman', 'sharia', 'hijab']),
#        list(['possibly', 'scam', 'divert', 'funding', 'community', 'could', 'possibly', 'scam', 'get']),
#        list(['heal', 'unity', 'creature']),
#        list(['coronavirus', 'tyranny', 'german', 'state', 'police', 'detain', 'maskless', 'elderly', 'cyclist', 'citizen', 'violate', 'chancellor', 'angela', 'merkel', 'lockd']),
#        list(['allahu', 'akbar', 'allahu', 'akbar', 'allahu', 'akbar', 'last', 'word', 'cockpit', 'flight']),
#        list(['take', 'name', 'main', 'parasitic', 'beneficiary', 'anti', 'semitism', 'journalistic', 'investigation']),
#        list(['rapist', 'black', 'call', 'rapist', 'call', 'pervert', 'downplay', 'black', 'crim']),
#        list(['assume', 'fight', 'back', 'know', 'one', 'actually', 'start', 'fight']),
#        list(['call', 'whatever', 'want', 'coca', 'cola', 'anti', 'white', 'actively', 'participate', 'war', 'wag']),
#        list(['eventually', 'go', 'consider', 'racist', 'white', 'person', 'deny', 'non', 'white', 'access', 'body']),
#        list(['daily', 'reminder', 'current', 'president', 'united', 'state', 'say', 'good', 'thing', 'found', 'stock', 'america']),
#        list(['assume', 'fight', 'back', 'know', 'one', 'actually', 'start', 'fight']),
#        list(['video', 'deserves', 'every', 'thumb', 'get']),
#        list(['left', 'protects', 'domestic', 'terrorist', 'whereas', 'right', 'abandon']),
#        list(['recent', 'psych', 'science', 'paper', 'use', 'national', 'iq', 'predict', 'stuff', 'ran', 'simple', 'probability', 'calculation', 'measur']),
#        list(['bodybuilding']),
#        list(['biden', 'legislate', 'executive', 'order', 'unless', 'dictator', 'also', 'biden', 'proceeds', 'sign', 'record', 'break']),
#        list(['black', 'life', 'matter', 'movement', 'nominate', 'nobel', 'peace', 'prize', 'via']),
#        list(['year', 'say', 'wag', 'war', 'white', 'people', 'finally', 'understand', 'sa']),
#        list(['george', 'conway', 'lie', 'national', 'tv', 'say', 'know', 'fellow', 'co', 'founder', 'lincoln', 'project', 'well', 'r']),
#        list(['people', 'draw', 'comparison', 'jeffrey', 'epstein', 'lincoln', 'project']),
#        list(['hence', 'social', 'justice', 'warrior', 'infect']),
#        list(['ok', 'groomers']),
#        list(['woman', 'march', 'silent', 'taxpayer', 'fund', 'german', 'school', 'put', 'hijab', 'non', 'muslim', 'german', 'girl', 'dress', 'rehearsal']),
#        list(['one', 'white', 'person', 'alive', 'today', 'ever', 'black', 'slave', 'one', 'black', 'person', 'alive', 'today', 'ever', 'white']),
#        list(['leftist', 'never', 'held', 'accountable', 'vicious', 'public', 'threat', 'violence', 'keep', 'make', 'trump']),
#        list(['bloody', 'man', 'throw', 'decapitate', 'head', 'window', 'onto', 'street', 'france', 'short', 'month', 'ago', 'islamic', 'migrant']),
#        list(['panic', 'kitchen', 'rebel', 'restaurateur', 'deprive', 'aid', 'bruno', 'le', 'maire']),
#        list(['post', 'still', 'anti', 'white', 'butthurt', 'black', 'history', 'month']),
#        list(['kind', 'interest', 'timing', 'soros', 'myanmar']),
#        list(['break', 'see', 'inside', 'germany', 'maximum', 'security', 'corona', 'jail', 'quarantine', 'violator', 'barbed', 'wire', 'amp', 'security', 'fence', 'surround']),
#        list(['want', 'socialism']),
#        list(['show', 'one', 'politician', 'corrupt', 'core']),
#        list(['warn', 'isi', 'order', 'wolf', 'attack', 'church', 'amp', 'police', 'spain', 'despite', 'anti', 'terrorist', 'unit', 'warn', 'left', 'wing', 'gov']),
#        list(['twitter', 'thousand', 'retweets', 'twitter', 'dozen', 'retweets', 'twitter', 'new', 'follower', 'daily', 'twitter', 'followe']),
#        list(['world', 'hijab', 'day', 'one', 'many', 'subtle', 'tactic', 'use', 'muslim', 'brotherhood', 'front', 'group', 'introduce', 'sharia', 'america', 'illino']),
#        list(['play', 'anja', 'speak', 'silver', 'silent', 'gold']),
#        list(['apparently', 'special', 'kind', 'hate', 'black', 'woman', 'experience', 'call', 'misogynoir', 'seriously']),
#        list(['biden', 'threat', 'global', 'security', 'china', 'ate', 'secretary', 'blinken', 'lunch', 'ccp', 'order', 'press', 'back', 'room']),
#        list(['report', 'government', 'dominate', 'committee', 'call', 'seat', 'inbound', 'flight', 'quarantine', 'place', 'australia']),
#        list(['make', 'farm', 'economically', 'viable', 'sustainable', 'enterprise', 'small', 'farmer', 'india', 'need', 'carefully', 'listen']),
#        list(['old', 'south', 'wealthy', 'white', 'allied', 'jewish', 'merchant', 'pamper', 'color', 'slave', 'class', 'mass', 'poor', 'white']),
#        list(['china', 'amp', 'iran', 'control', 'biden', 'commie', 'amp', 'islamic', 'supremacist', 'long', 'history', 'unite', 'destroy', 'common', 'enemy']),
#        list(['natural', 'redhead', 'rare', 'people', 'planet', 'easily', 'one', 'beautiful', 'anyone', 'natural']),
#        list(['daniel', 'year', 'old', 'athletic', 'intensive', 'care', 'bfm', 'tv', 'manipulation']),
#        list(['imagine', 'power', 'like', 'power', 'declare', 'act', 'criminal', 'ability', 'declare', 'anti', 'semit']),
#        list(['salute']),
#        list(['terror', 'attack', 'update', 'afghani', 'migrant', 'behind', 'stab', 'sweden', 'medium', 'reporting', 'terrorist', 'suffer']),
#        list(['play', 'celine', 'dion', 'leave', 'without', 'eurovision', 'grand', 'prix']),
#        list(['break', 'swedish', 'news', 'reporting', 'suspect', 'first', 'enter', 'country']),
#        list(['new', 'swedish', 'school', 'report', 'jew', 'malm', 'enemy', 'arab', 'student', 'craze', 'hitler', 'today']),
#        list(['thus', 'globalists', 'use', 'power', 'compete', 'opposition', 'make', 'opposition', 'illegal']),
#        list(['break', 'terror', 'attack', 'sweden', 'eight', 'injured', 'vetlanda', 'video', 'police', 'refuse', 'answer', 'medium', 'question']),
#        list(['mine', 'christine']),
#        list(['good', 'news', 'would', 'prefer', 'rehabilitation', 'center']),
#        list(['ten', 'people', 'slaughter', 'syrian', 'muslim', 'refugee', 'ahmad', 'al', 'issa', 'white', 'non', 'muslim', 'terrorist', 'attack', 'also', 'goin']),
#        list(['america', 'deal', 'deadly', 'islamic', 'terrorist', 'attack', 'colorado', 'jihadist', 'kill', 'mali', 'one']),
#        list(['happen', 'make', 'american', 'listen', 'put', 'video', 'year', 'ago', 'man', 'interrogate', 'islamic']),
#        list(['venezuela', 'start', 'free', 'distribution', 'drug', 'covid']),
#        list(['u', 'call', 'suarez', 'something', 'wen', 'call', 'u', 'nigger', 'u', 'bitch']),
#        list(['white', 'supremacist', 'keep', 'get', 'darker', 'darker', 'day']),
#        list(['bose', 'dk', 'sit', 'naked']),
#        list(['piece', 'bravery', 'alain', 'soral', 'ntm', 'alain', 'soral', 'fr', 'jus']),
#        list(['demographic', 'jihad', 'swedish', 'government', 'lie', 'massive', 'migration', 'number', 'video', 'within', 'generation', 'sweden', 'third', 'large']),
#        list(['cnn', 'rest', 'liberal', 'medium', 'fake', 'plan', 'attack', 'today', 'u', 'capitol', 'go', 'today']),
#        list(['think', 'even', 'one', 'race', 'government', 'target', 'deprogramming', 'know', 'becau']),
#        list(['tell', 'russia', 'never', 'cucked', 'j']),
#        list(['timeline', 'evidence', 'lazy', 'choice']),
#        list(['everything', 'come', 'existence', 'creates', 'opposite', 'light', 'darkness', 'heat', 'cold', 'life', 'death', 'matter', 'anti']),
#        list(['call', 'mass', 'shoot', 'however', 'medium', 'report', 'shooter', 'white']),
#        list(['wow']),
#        list(['main', 'stream', 'medium', 'work', 'international', 'banker', 'international', 'banker', 'fully', 'human', 'hurt', 'u']),
#        list(['create', 'beast', 'finally', 'bring']),
#        list(['tell', 'everyone', 'year', 'ever', 'give', 'scandinavian', 'brother', 'sister', 'war', 'th']),
#        list(['even', 'know', 'could', 'shoot', 'mile', 'wow', 'seriousness', 'idiot', 'like', 'allow']),
#        list(['biden', 'sign', 'executive', 'order', 'first', 'ten', 'day', 'president', 'anyone', 'sign', 'many', 'executive', 'order']),
#        list(['play', 'hansi', 'hinterseer', 'god', 'life', 'earth']),
#        list(['heard', 'psycho', 'back', 'send', 'agra', 'soon']),
#        list(['play', 'bob', 'benny', 'love', 'anyway']),
#        list(['hostile', 'people', 'really', 'except', 'crazy', 'notion', 'planet', 'father', 'god', 'chose']),
#        list(['hebrew', 'mythology', 'make', 'race', 'slave', 'benefit']),
#        list(['pride', 'wake']),
#        list(['feel', 'whole', 'lot', 'well', 'impend', 'collapse', 'western', 'civilization', 'white', 'people', 'form', 'group']),
#        list(['neat', 'idea', 'fiction', 'novel', 'anyone', 'interested', 'write', 'bunch', 'retire', 'sof', 'operator', 'use']),
#        list(['read', 'write', 'wall', 'yet', 'guy', 'war', 'wag', 'white', 'man', 'ever', 'surren']),
#        list(['actually', 'sour', 'though', 'pickle', 'except', 'cabbage', 'instead', 'cucumber', 'delicio']),
#        list(['white', 'men', 'deserve', 'job', 'white', 'men', 'tell', 'white', 'men', 'persecute']),
#        list(['safely', 'enjoy', 'stroll', 'around', 'mall', 'anymore', 'virtually', 'every', 'mall', 'go']),
#        list(['philosophy', 'ideology', 'tactic', 'method', 'optic', 'superior', 'others', 'feel']),
#        list(['play', 'hut', 'jordan', 'jay', 'idetto', 'mood']),
#        list(['warn', 'joe', 'biden', 'radical', 'hud', 'secretary', 'marcia', 'fudge', 'threat', 'america', 'watch', 'like', 'many', 'others', 'biden', 'admin']),
#        list(['think', 'possible', 'man', 'produce', 'much', 'estrogen']),
#        list(['seethe', 'harder', 'parasite', 'freak']),
#        list(['russia', 'international', 'regulation', 'social', 'medium', 'moderation']),
#        list(['really', 'live', 'white', 'supremacist', 'country', 'repeatedly', 'told', 'would', 'law', 'make']),
#        list(['let', 'billionaire', 'cry']),
#        list(['people', 'die', 'vaccination', 'accord', 'pej', 'bos', 'cichutek', 'bpk', 'however', 'people']),
#        list(['fiery', 'mostly', 'peaceful', 'prize']),
#        list(['enough', 'mr', 'laschet', 'enough', 'merkel', 'cry', 'help', 'hairdresser', 'bianka', 'fuse', 'burn']),
#        list(['new', 'regime', 'go', 'force', 'mass', 'obey', 'send', 'people', 'disappear']),
#        list(['term', 'radical', 'thrown', 'around', 'pretty', 'loosely', 'day', 'literally', 'anything', 'left', 'like']),
#        list(['play', 'nicole', 'wonderful']),
#        list(['antifa', 'always', 'corporate', 'manufacture', 'product', 'anarcho', 'marxism', 'package', 'sell', 'capitalist', 'impre']),
#        list(['population', 'control', 'group', 'cheer', 'biden', 'force', 'taxpayer', 'fund', 'overseas', 'abortion', 'trump', 'like', 'reagan', 'stop', 'taxpayer', 'fun']),
#        list(['surprised', 'new', 'age', 'neo', 'marxist', 'refuse', 'join', 'take', 'wall', 'street', 'crook']),
#        list(['france', 'freak', 'theory', 'small', 'bubble', 'heat', 'pan', 'water', 'first', 'surface']),
#        list(['two', 'tower', 'hand', 'signal', 'hmm']),
#        list(['attack', 'u', 'military', 'eleven', 'soldier', 'fort', 'bliss', 'texas', 'injured', 'drinking', 'antifreeze', 'believe', 'dr']),
#        list(['try', 'say', 'jew', 'stock', 'market', 'beating', 'game', 'anti', 'semitism']),
#        list(['dr', 'fauci', 'covid', 'expert', 'back', 'march']),
#        list(['great', 'reset', 'big', 'cleaning', 'episode', 'great', 'reset', 'health']),
#        list(['boris', 'johnson', 'mr', 'crisis', 'mr', 'liar', 'mr', 'clueless', 'mr', 'corrupt', 'mr', 'racist', 'mr', 'money', 'grabber', 'mr', 'public', 'heal']),
#        list(['people', 'think', 'boris', 'johnson', 'resign', 'prime', 'minister', 'think', 'continue', 'office', 'accord']),
#        list(['hypothetical', 'anymore', 'matter', 'matter', 'government', 'force', 'prep']),
#        list(['baaaaaaaaaaaaa']), list(['best', 'really']),
#        list(['remember', 'current', 'era', 'become', 'naturally', 'manufacture', 'slowly', 'generation']),
#        list(['excuse', 'pedophile', 'time', 'never', 'tolerate', 'white', 'person', 'believe', 'white', 'life', 'matter']),
#        list(['appal', 'homeless', 'queue', 'food', 'last', 'night', 'soup', 'kitchen', 'freeze', 'condition', 'ten', 'year', 'toryism']),
#        list(['watch', 'first', 'part', 'minute', 'great', 'reset', 'great', 'reset', 'spring', 'cleaning', 'great', 'r']),
#        list(['much', 'institutional', 'white', 'supremacy', 'racism']),
#        list(['literally', 'nothing', 'label', 'racist', 'white', 'supremacist', 'pathological', 'hatred', 'white', 'men']),
#        list(['right', 'give', 'british', 'journalism', 'coverage', 'brexit', 'covid']),
#        list(['end', 'attack', 'natural', 'order', 'era', 'insanity', 'become', 'universal', 'new', 'age', 'religion']),
#        list(['historically', 'speak', 'virtually', 'every', 'time', 'communism', 'come', 'power', 'regime', 'manufacture', 'artificial', 'famine']),
#        list(['know', 'beat', 'white', 'people', 'say', 'care', 'white', 'black', 'yellow', 'blue', 'purple']),
#        list(['know', 'go', 'use', 'eternal', 'justification', 'rob', 'freedom', 'right']),
#        list(['diversity', 'strength', 'army', 'choose', 'diversity']),
#        list(['downfall', 'america', 'sum', 'single', 'image']),
#        list(['astra', 'zeneca', 'prove', 'dangerous', 'yet', 'country', 'throughout', 'europe', 'push', 'citizen', 'meanwhile', 'famous', 'german', 'doctor']),
#        list(['break', 'germany', 'suspends', 'astra', 'zeneca', 'vaccination', 'although', 'report', 'side', 'effect', 'increase', 'several', 'st']),
#        list(['year', 'literal', 'white', 'genocide']),
#        list(['non', 'white', 'responsible', 'action', 'black', 'gun', 'gang', 'motivate', 'mass', 'sh']),
#        list(['advanced', 'civilization']),
#        list(['hey', 'general', 'heard', 'retire', 'general', 'major', 'ig', 'investigation', 'involve', 'army', 'hid']),
#        list(['interestingly', 'enough', 'know', 'sole', 'authority', 'define', 'word', 'like', 'hate', 'racism', 'bigotry', 'extremis']),
#        list(['new', 'comic']),
#        list(['diversity', 'strength', 'army', 'choose', 'diversity']),
#        list(['particular', 'point', 'time', 'obvious', 'naked', 'eye', 'race', 'people', 'happier', 'segregation']),
#        list(['freak', 'wonder', 'white', 'nationalism', 'rise', 'world']),
#        list(['get', 'ready', 'people', 'government', 'move']),
#        list(['ever', 'notice', 'literally', 'sea', 'protest', 'medium', 'like', 'hype', 'sign', 'write', 'english']),
#        list(['detest', 'people', 'every', 'part', 'medium', 'idiot', 'support', 'imagine', 'guy', 'n', 'h', 'ei', 'r', 'si', 'de', 'nobod']),
#        list(['modi', 'ji', 'slogan', 'self', 'reliance', 'penetrate', 'even', 'among', 'love', 'couple']),
#        list(['pride', 'india', 'rajputana', 'chittorgarh', 'fort']),
#        list(['hesitate', 'worn', 'bottom', 'people', 'see', 'inside', 'let', 'go', 'colorful']),
#        list(['india', 'innovative', 'thrust', 'jai', 'swadeshi']),
#        list(['around', 'world', 'white', 'people', 'get', 'dangerously', 'fed', 'violently', 'attack', 'forei']),
#        list(['fuck', 'petty', 'go', 'year', 'old', 'man', 'weak', 'pathetic', 'creature']),
#        list(['accord', 'news', 'source', 'suspect', 'detain', 'release', 'name', 'description', 'virtual'])],
#       dtype=object)

# %%
coherence_c_v = CoherenceModel(texts = docs, topics=texts, corpus=corpus, dictionary = dictionary,  coherence='c_v').get_coherence()
coherence_c_v
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in _ensure_elements_are_ids(self, topic)
#     444         try:
# --> 445             return np.array([self.dictionary.token2id[token] for token in topic])
#     446         except KeyError:  # might be a list of token ids already, but let's verify all in dict
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in <listcomp>(.0)
#     444         try:
# --> 445             return np.array([self.dictionary.token2id[token] for token in topic])
#     446         except KeyError:  # might be a list of token ids already, but let's verify all in dict
#
# KeyError: 'one'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28372/2247015188.py in <module>
# ----> 1 coherence_c_v = CoherenceModel(texts = docs, topics=texts, corpus=corpus, dictionary = dictionary,  coherence='c_v').get_coherence()
#       2 coherence_c_v
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in __init__(self, model, topics, texts, corpus, dictionary, window_size, keyed_vectors, coherence, topn, processes)
#     210         self._accumulator = None
#     211         self._topics = None
# --> 212         self.topics = topics
#     213
#     214         self.processes = processes if processes >= 1 else max(1, mp.cpu_count() - 1)
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in topics(self, topics)
#     425             new_topics = []
#     426             for topic in topics:
# --> 427                 topic_token_ids = self._ensure_elements_are_ids(topic)
#     428                 new_topics.append(topic_token_ids)
#     429
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in _ensure_elements_are_ids(self, topic)
#     446         except KeyError:  # might be a list of token ids already, but let's verify all in dict
#     447             topic = (self.dictionary.id2token[_id] for _id in topic)
# --> 448             return np.array([self.dictionary.token2id[token] for token in topic])
#     449
#     450     def _update_accumulator(self, new_topics):
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in <listcomp>(.0)
#     446         except KeyError:  # might be a list of token ids already, but let's verify all in dict
#     447             topic = (self.dictionary.id2token[_id] for _id in topic)
# --> 448             return np.array([self.dictionary.token2id[token] for token in topic])
#     449
#     450     def _update_accumulator(self, new_topics):
#
# ~\anaconda3\lib\site-packages\gensim\models\coherencemodel.py in <genexpr>(.0)
#     445             return np.array([self.dictionary.token2id[token] for token in topic])
#     446         except KeyError:  # might be a list of token ids already, but let's verify all in dict
# --> 447             topic = (self.dictionary.id2token[_id] for _id in topic)
#     448             return np.array([self.dictionary.token2id[token] for token in topic])
#     449
#
# KeyError: 'white'

# %%
coherence_u_mass = CoherenceModel(model=model, corpus=corpus, coherence='u_mass').get_coherence()
coherence_u_mass
