# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../helpers_python')
from pre_processing import *
from lda_helpers import * 

import gensim
from gsdmm import MovieGroupProcess

# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /Users/robinjaccard/opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload

# %%
country = 'France'

# Load data
df = load_data_lda(country)

# %%
df
# Out:
#        Unnamed: 0                 created_at  \
# 139           138  2021-03-18 02:01:59+00:00
# 232           232  2021-03-17 16:06:03+00:00
# 256           256  2021-03-17 16:51:43+00:00
# 262           261  2021-03-18 01:01:38+00:00
# 265           264  2021-03-18 01:50:10+00:00
# ...           ...                        ...
# 22749       23029  2021-02-09 15:14:09+00:00
# 22751       23031  2021-02-09 15:04:19+00:00
# 22767       23046  2021-02-09 22:28:46+00:00
# 22778       23058  2021-02-09 19:15:08+00:00
# 22785       23064  2021-02-09 20:12:17+00:00
#
#                                                     text  \
# 139      *Muslims commit multiple terrorist attacks a...
# 232      The "toxic upbringing/environment" is the an...
# 256      Nothing is allowed to be White.If it's White...
# 262      The writing is on the wall. The White race i...
# 265      "T'es financée par les Rothschild" : retour ...
# ...                                                  ...
# 22749    अब काहे सकपका रही हो, इसीलिये तो नीचे नहीं प...
# 22751     INDIA INNOVATIVE THRUST! JAI SWADESHI!     ...
# 22767      All around the world, White people are get...
# 22778    How fucking petty... Going after a   year ol...
# 22785    According to news sources, a suspect has bee...
#
#                                                   source  \
# 139    <a href="http://twitter.com/download/iphone" r...
# 232    <a href="http://twitter.com/download/android" ...
# 256    <a href="http://twitter.com/download/android" ...
# 262    <a href="https://mobile.twitter.com" rel="nofo...
# 265    <a href="https://mobile.twitter.com" rel="nofo...
# ...                                                  ...
# 22749  <a href="https://mobile.twitter.com" rel="nofo...
# 22751  <a href="http://twitter.com/download/android" ...
# 22767  <a href="http://twitter.com/download/iphone" r...
# 22778  <a href="http://twitter.com/download/android" ...
# 22785  <a href="http://twitter.com/download/iphone" r...
#
#                                               translated  \
# 139    *Muslims commit multiple terrorist attacks all...
# 232    The "toxic upbringing/environment" is the anti...
# 256    Nothing is allowed to be White.If it's White, ...
# 262    The writing is on the wall. The White race is ...
# 265    "You're financed by the Rothschilds": return t...
# ...                                                  ...
# 22749  Now why are you hesitating, that's why you hav...
# 22751    INDIA INNOVATIVE THRUST! JAI SWADESHI!        …
# 22767  All around the world, White people are getting...
# 22778  How fucking petty... Going after a   year old ...
# 22785  According to news sources, a suspect has been ...
#
#                                                    clean    whcs  duplicated  \
# 139    muslim commit multiple terrorist attack across...  France        True
# 232    toxic upbringing environment anti white hatred...  France        True
# 256       nothing allow white white problem need address  France        True
# 262    write wall white race slat genocide hyperbole ...  France        True
# 265    ficed rothschild return face face reality hyst...  France       False
# ...                                                  ...     ...         ...
# 22749  hesitate worn bottom people see inside let go ...  France       False
# 22751               india innovative thrust jai swadeshi  France       False
# 22767  around world white people get dangerously fed ...  France        True
# 22778  fuck petty go year old man weak pathetic creature  France        True
# 22785  accord news source suspect detain release name...  France        True
#
#       language
# 139    English
# 232    English
# 256    English
# 262    English
# 265     French
# ...        ...
# 22749    Hindi
# 22751  English
# 22767  English
# 22778  English
# 22785  English
#
# [900 rows x 9 columns]

# %%
df["clean"] = df["clean"].apply(lambda x: str(x).split()) # transform the strings into arrays of words

# %%
# cast tweets to numpy array
docs = df.clean.to_numpy()

# create dictionary of all words in all documents
dictionary = gensim.corpora.Dictionary(docs)

# %%
# create variable containing size of dictionary
vocab_length = len(dictionary)

# create bag of words dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
# initialize GSDMM
gsdmm = MovieGroupProcess(K=15, alpha=0.1, beta=0.3, n_iters=15)

# %%
# fit GSDMM model
y = gsdmm.fit(docs, vocab_length)
# Out:
# In stage 0: transferred 742 clusters with 15 clusters populated
# In stage 1: transferred 493 clusters with 15 clusters populated
# In stage 2: transferred 403 clusters with 15 clusters populated
# In stage 3: transferred 305 clusters with 15 clusters populated
# In stage 4: transferred 286 clusters with 15 clusters populated
# In stage 5: transferred 263 clusters with 15 clusters populated
# In stage 6: transferred 283 clusters with 15 clusters populated
# In stage 7: transferred 248 clusters with 15 clusters populated
# In stage 8: transferred 283 clusters with 15 clusters populated
# In stage 9: transferred 236 clusters with 14 clusters populated
# In stage 10: transferred 233 clusters with 15 clusters populated
# In stage 11: transferred 246 clusters with 14 clusters populated
# In stage 12: transferred 232 clusters with 15 clusters populated
# In stage 13: transferred 233 clusters with 14 clusters populated
# In stage 14: transferred 237 clusters with 13 clusters populated

# %%
# print number of documents per topic
doc_count = np.array(gsdmm.cluster_doc_count)
print('Number of documents per topic :', doc_count)

# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-15:][::-1]
print('Most important clusters (by number of docs inside):', top_index)

# define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

# get top words in topics
top_words(gsdmm.cluster_word_distribution, top_index, 10)
# Out:
# Number of documents per topic : [ 33  24  77  78  88 102  30  61 298  29   0   0  16  48  16]
# Most important clusters (by number of docs inside): [ 8  5  4  3  2  7 13  0  6  9  1 14 12 11 10]
#
# Cluster 8 : [('white', 155), ('people', 88), ('black', 35), ('say', 32), ('go', 29), ('get', 27), ('u', 26), ('war', 23), ('anti', 23), ('want', 21)]
#
# Cluster 5 : [('muslim', 27), ('attack', 15), ('terrorist', 13), ('police', 12), ('year', 12), ('new', 10), ('one', 10), ('islamic', 9), ('amp', 9), ('migrant', 9)]
#
# Cluster 4 : [('trump', 22), ('cpac', 12), ('people', 10), ('every', 8), ('want', 8), ('time', 7), ('one', 7), ('president', 7), ('party', 7), ('berry', 6)]
#
# Cluster 3 : [('one', 13), ('many', 10), ('people', 9), ('need', 8), ('country', 8), ('biden', 7), ('minister', 7), ('prime', 6), ('first', 6), ('get', 6)]
#
# Cluster 2 : [('biden', 15), ('left', 13), ('border', 12), ('wing', 12), ('germany', 11), ('video', 10), ('u', 9), ('open', 8), ('german', 8), ('migrant', 8)]
#
# Cluster 7 : [('amp', 18), ('left', 14), ('islamic', 10), ('attack', 9), ('threat', 9), ('like', 8), ('biden', 7), ('terrorist', 7), ('expose', 7), ('control', 6)]
#
# Cluster 13 : [('twitter', 11), ('year', 10), ('great', 9), ('follower', 8), ('reset', 7), ('new', 6), ('people', 5), ('think', 5), ('thousand', 4), ('like', 4)]
#
# Cluster 0 : [('religion', 5), ('major', 4), ('two', 4), ('boy', 4), ('human', 4), ('anyone', 3), ('jew', 3), ('american', 3), ('religious', 3), ('case', 3)]
#
# Cluster 6 : [('woman', 15), ('hijab', 6), ('sharia', 4), ('afrin', 4), ('let', 4), ('cry', 4), ('together', 3), ('amp', 3), ('via', 3), ('day', 3)]
#
# Cluster 9 : [('play', 16), ('face', 5), ('scar', 3), ('cpac', 2), ('show', 2), ('rino', 2), ('nikki', 2), ('haley', 2), ('day', 2), ('fantasy', 2)]
#
# Cluster 1 : [('nigga', 11), ('soral', 10), ('lil', 10), ('alain', 7), ('answer', 4), ('episode', 3), ('de', 3), ('big', 3), ('piece', 2), ('bravery', 2)]
#
# Cluster 14 : [('always', 3), ('marxism', 2), ('shri', 2), ('ji', 2), ('host', 2), ('time', 2), ('social', 2), ('firearm', 2), ('year', 2), ('old', 2)]
#
# Cluster 12 : [('mr', 8), ('bit', 3), ('sex', 3), ('enough', 3), ('every', 2), ('people', 2), ('law', 2), ('enforcement', 2), ('earn', 2), ('hate', 2)]
#
# Cluster 11 : []
#
# Cluster 10 : []

# %% [markdown]
# ## Metric

# %%
from gensim.models import CoherenceModel

# %%
# define function to get words in topics
def get_topics_lists(model, top_clusters, n_words):
    '''
    Gets lists of words in topics as a list of lists.
    
    model: gsdmm instance
    top_clusters:  numpy array containing indices of top_clusters
    n_words: top n number of words to include
    
    '''
    # create empty list to contain topics
    topics = []
    
    # iterate over top n clusters
    for cluster in top_clusters:
        #create sorted dictionary of word distributions
        sorted_dict = sorted(model.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:n_words]
         
        #create empty list to contain words
        topic = []
        
        #iterate over top n words in topic
        for k,v in sorted_dict:
            #append words to topic list
            topic.append(k)
            
        #append topics to topics list   
        if len(topic) != 0:
            topics.append(topic)
    
    return topics

# %%
topics = get_topics_lists(gsdmm, top_index, 10)

# %%
# evaluate model using Topic Coherence score
cm_gsdmm = CoherenceModel(topics=topics, 
                          dictionary=dictionary, 
                          corpus=bow_corpus, 
                          texts=docs, 
                          coherence='c_v')

# get coherence value
coherence_gsdmm = cm_gsdmm.get_coherence()  

print(coherence_gsdmm)
# Out:
# 0.35696819691336934

# %% [markdown]
# ## Grid Search

# %%
alphas = [0.001, 0.01, 0.1, 0.2]
betas = [0.001, 0.01, 0.1, 0.2]
n_iters = [5, 10, 15, 20]

# %%
best_coherence = -1000
for i in alphas:
    for j in betas:
        for n in n_iters:
            gsdmm = MovieGroupProcess(K=10, alpha=i, beta=j, n_iters=n)
            y = gsdmm.fit(docs, vocab_length)
            doc_count = np.array(gsdmm.cluster_doc_count)
            top_index = doc_count.argsort()[-15:][::-1]
            topics = get_topics_lists(gsdmm, top_index, 10) 
            cm_gsdmm = CoherenceModel(topics=topics, 
                          dictionary=dictionary, 
                          corpus=bow_corpus, 
                          texts=docs, 
                          coherence='c_v')

            # get coherence value
            coherence_gsdmm = cm_gsdmm.get_coherence() 
            if coherence_gsdmm > best_coherence:
                best_coherence = coherence_gsdmm
            print("alpha "+str(i)+" betas "+str(j))
            print("Coherence: "+str(coherence_gsdmm))
            print("Best coherence: "+str(best_coherence))
# Out:
# In stage 0: transferred 675 clusters with 10 clusters populated
# In stage 1: transferred 394 clusters with 10 clusters populated
# In stage 2: transferred 279 clusters with 10 clusters populated
# In stage 3: transferred 229 clusters with 10 clusters populated
# In stage 4: transferred 190 clusters with 10 clusters populated
# alpha 0.0001 betas 0.1
# Coherence: 0.34791537361503355
# Best coherence: 0.34791537361503355
# In stage 0: transferred 683 clusters with 10 clusters populated
# In stage 1: transferred 357 clusters with 10 clusters populated
# In stage 2: transferred 251 clusters with 10 clusters populated
# In stage 3: transferred 213 clusters with 10 clusters populated
# In stage 4: transferred 206 clusters with 10 clusters populated
# In stage 5: transferred 198 clusters with 10 clusters populated
# In stage 6: transferred 198 clusters with 10 clusters populated
# In stage 7: transferred 188 clusters with 10 clusters populated
# In stage 8: transferred 173 clusters with 10 clusters populated
# In stage 9: transferred 170 clusters with 10 clusters populated
# alpha 0.0001 betas 0.1
# Coherence: 0.367981970912647
# Best coherence: 0.367981970912647
# In stage 0: transferred 658 clusters with 10 clusters populated
# In stage 1: transferred 360 clusters with 10 clusters populated
# In stage 2: transferred 257 clusters with 10 clusters populated
# In stage 3: transferred 213 clusters with 10 clusters populated
# In stage 4: transferred 194 clusters with 10 clusters populated
# In stage 5: transferred 184 clusters with 10 clusters populated
# In stage 6: transferred 172 clusters with 10 clusters populated
# In stage 7: transferred 170 clusters with 10 clusters populated
# In stage 8: transferred 180 clusters with 10 clusters populated
# In stage 9: transferred 184 clusters with 10 clusters populated
# In stage 10: transferred 162 clusters with 10 clusters populated
# In stage 11: transferred 163 clusters with 10 clusters populated
# In stage 12: transferred 165 clusters with 10 clusters populated
# In stage 13: transferred 163 clusters with 10 clusters populated
# In stage 14: transferred 144 clusters with 10 clusters populated
# alpha 0.0001 betas 0.1
# Coherence: 0.34140438110980054
# Best coherence: 0.367981970912647
# In stage 0: transferred 690 clusters with 10 clusters populated
# In stage 1: transferred 375 clusters with 10 clusters populated
# In stage 2: transferred 268 clusters with 10 clusters populated
# In stage 3: transferred 253 clusters with 10 clusters populated
# In stage 4: transferred 219 clusters with 10 clusters populated
# In stage 5: transferred 185 clusters with 10 clusters populated
# In stage 6: transferred 206 clusters with 10 clusters populated
# In stage 7: transferred 200 clusters with 10 clusters populated
# In stage 8: transferred 186 clusters with 10 clusters populated
# In stage 9: transferred 177 clusters with 10 clusters populated
# In stage 10: transferred 173 clusters with 10 clusters populated
# In stage 11: transferred 158 clusters with 10 clusters populated
# In stage 12: transferred 166 clusters with 10 clusters populated
# In stage 13: transferred 157 clusters with 10 clusters populated
# In stage 14: transferred 150 clusters with 10 clusters populated
# In stage 15: transferred 148 clusters with 10 clusters populated
# In stage 16: transferred 161 clusters with 10 clusters populated
# In stage 17: transferred 162 clusters with 10 clusters populated
# In stage 18: transferred 153 clusters with 10 clusters populated
# In stage 19: transferred 153 clusters with 10 clusters populated
# alpha 0.0001 betas 0.1
# Coherence: 0.3237781205594107
# Best coherence: 0.367981970912647
# In stage 0: transferred 702 clusters with 10 clusters populated
# In stage 1: transferred 407 clusters with 10 clusters populated
# In stage 2: transferred 288 clusters with 10 clusters populated
# In stage 3: transferred 248 clusters with 10 clusters populated
# In stage 4: transferred 238 clusters with 10 clusters populated
# alpha 0.0001 betas 0.15
# Coherence: 0.3629142191385878
# Best coherence: 0.367981970912647
# In stage 0: transferred 686 clusters with 10 clusters populated
# In stage 1: transferred 396 clusters with 10 clusters populated
# In stage 2: transferred 284 clusters with 10 clusters populated
# In stage 3: transferred 250 clusters with 10 clusters populated
# In stage 4: transferred 244 clusters with 10 clusters populated
# In stage 5: transferred 234 clusters with 10 clusters populated
# In stage 6: transferred 233 clusters with 10 clusters populated
# In stage 7: transferred 198 clusters with 10 clusters populated
# In stage 8: transferred 183 clusters with 10 clusters populated
# In stage 9: transferred 184 clusters with 10 clusters populated
# alpha 0.0001 betas 0.15
# Coherence: 0.33399276593370864
# Best coherence: 0.367981970912647
# In stage 0: transferred 713 clusters with 10 clusters populated
# In stage 1: transferred 399 clusters with 10 clusters populated
# In stage 2: transferred 303 clusters with 10 clusters populated
# In stage 3: transferred 230 clusters with 10 clusters populated
# In stage 4: transferred 218 clusters with 10 clusters populated
# In stage 5: transferred 214 clusters with 10 clusters populated
# In stage 6: transferred 200 clusters with 10 clusters populated
# In stage 7: transferred 203 clusters with 10 clusters populated
# In stage 8: transferred 193 clusters with 10 clusters populated
# In stage 9: transferred 176 clusters with 10 clusters populated
# In stage 10: transferred 174 clusters with 10 clusters populated
# In stage 11: transferred 164 clusters with 10 clusters populated
# In stage 12: transferred 169 clusters with 10 clusters populated
# In stage 13: transferred 178 clusters with 10 clusters populated
# In stage 14: transferred 186 clusters with 10 clusters populated
# alpha 0.0001 betas 0.15
# Coherence: 0.37470531521194117
# Best coherence: 0.37470531521194117
# In stage 0: transferred 693 clusters with 10 clusters populated
# In stage 1: transferred 386 clusters with 10 clusters populated
# In stage 2: transferred 297 clusters with 10 clusters populated
# In stage 3: transferred 260 clusters with 10 clusters populated
# In stage 4: transferred 226 clusters with 10 clusters populated
# In stage 5: transferred 217 clusters with 10 clusters populated
# In stage 6: transferred 211 clusters with 10 clusters populated
# In stage 7: transferred 198 clusters with 10 clusters populated
# In stage 8: transferred 197 clusters with 10 clusters populated
# In stage 9: transferred 192 clusters with 10 clusters populated
# In stage 10: transferred 198 clusters with 10 clusters populated
# In stage 11: transferred 175 clusters with 10 clusters populated
# In stage 12: transferred 164 clusters with 10 clusters populated
# In stage 13: transferred 168 clusters with 10 clusters populated
# In stage 14: transferred 186 clusters with 10 clusters populated
# In stage 15: transferred 183 clusters with 10 clusters populated
# In stage 16: transferred 173 clusters with 10 clusters populated
# In stage 17: transferred 173 clusters with 10 clusters populated
# In stage 18: transferred 171 clusters with 10 clusters populated
# In stage 19: transferred 185 clusters with 10 clusters populated
# alpha 0.0001 betas 0.15
# Coherence: 0.30638093269579003
# Best coherence: 0.37470531521194117
# In stage 0: transferred 695 clusters with 10 clusters populated
# In stage 1: transferred 411 clusters with 10 clusters populated
# In stage 2: transferred 324 clusters with 10 clusters populated
# In stage 3: transferred 265 clusters with 10 clusters populated
# In stage 4: transferred 253 clusters with 10 clusters populated
# alpha 0.0001 betas 0.2
# Coherence: 0.3489734596870939
# Best coherence: 0.37470531521194117
# In stage 0: transferred 697 clusters with 10 clusters populated
# In stage 1: transferred 452 clusters with 10 clusters populated
# In stage 2: transferred 318 clusters with 10 clusters populated
# In stage 3: transferred 275 clusters with 10 clusters populated
# In stage 4: transferred 265 clusters with 10 clusters populated
# In stage 5: transferred 241 clusters with 10 clusters populated
# In stage 6: transferred 235 clusters with 10 clusters populated
# In stage 7: transferred 214 clusters with 10 clusters populated
# In stage 8: transferred 210 clusters with 10 clusters populated
# In stage 9: transferred 212 clusters with 10 clusters populated
# alpha 0.0001 betas 0.2
# Coherence: 0.36059687635442106
# Best coherence: 0.37470531521194117
# In stage 0: transferred 702 clusters with 10 clusters populated
# In stage 1: transferred 403 clusters with 10 clusters populated
# In stage 2: transferred 319 clusters with 10 clusters populated
# In stage 3: transferred 285 clusters with 10 clusters populated
# In stage 4: transferred 242 clusters with 10 clusters populated
# In stage 5: transferred 228 clusters with 10 clusters populated
# In stage 6: transferred 236 clusters with 10 clusters populated
# In stage 7: transferred 205 clusters with 10 clusters populated
# In stage 8: transferred 206 clusters with 10 clusters populated
# In stage 9: transferred 223 clusters with 10 clusters populated
# In stage 10: transferred 212 clusters with 10 clusters populated
# In stage 11: transferred 206 clusters with 10 clusters populated
# In stage 12: transferred 215 clusters with 10 clusters populated
# In stage 13: transferred 204 clusters with 10 clusters populated
# In stage 14: transferred 204 clusters with 10 clusters populated
# alpha 0.0001 betas 0.2
# Coherence: 0.3408376118638094
# Best coherence: 0.37470531521194117
# In stage 0: transferred 695 clusters with 10 clusters populated
# In stage 1: transferred 426 clusters with 10 clusters populated
# In stage 2: transferred 310 clusters with 10 clusters populated
# In stage 3: transferred 269 clusters with 10 clusters populated
# In stage 4: transferred 256 clusters with 10 clusters populated
# In stage 5: transferred 235 clusters with 10 clusters populated
# In stage 6: transferred 245 clusters with 10 clusters populated
# In stage 7: transferred 240 clusters with 10 clusters populated
# In stage 8: transferred 232 clusters with 10 clusters populated
# In stage 9: transferred 210 clusters with 10 clusters populated
# In stage 10: transferred 194 clusters with 10 clusters populated
# In stage 11: transferred 183 clusters with 10 clusters populated
# In stage 12: transferred 204 clusters with 10 clusters populated
# In stage 13: transferred 217 clusters with 10 clusters populated
# In stage 14: transferred 210 clusters with 10 clusters populated
# In stage 15: transferred 210 clusters with 10 clusters populated
# In stage 16: transferred 211 clusters with 10 clusters populated
# In stage 17: transferred 204 clusters with 10 clusters populated
# In stage 18: transferred 208 clusters with 10 clusters populated
# In stage 19: transferred 187 clusters with 10 clusters populated
# alpha 0.0001 betas 0.2
# Coherence: 0.3770413228089349
# Best coherence: 0.3770413228089349
# In stage 0: transferred 686 clusters with 10 clusters populated
# In stage 1: transferred 424 clusters with 10 clusters populated
# In stage 2: transferred 332 clusters with 10 clusters populated
# In stage 3: transferred 306 clusters with 10 clusters populated
# In stage 4: transferred 317 clusters with 10 clusters populated
# alpha 0.0001 betas 0.25
# Coherence: 0.31988021619755974
# Best coherence: 0.3770413228089349
# In stage 0: transferred 707 clusters with 10 clusters populated
# In stage 1: transferred 402 clusters with 10 clusters populated
# In stage 2: transferred 341 clusters with 10 clusters populated
# In stage 3: transferred 275 clusters with 10 clusters populated
# In stage 4: transferred 275 clusters with 10 clusters populated
# In stage 5: transferred 251 clusters with 10 clusters populated
# In stage 6: transferred 243 clusters with 10 clusters populated
# In stage 7: transferred 241 clusters with 10 clusters populated
# In stage 8: transferred 232 clusters with 10 clusters populated
# In stage 9: transferred 235 clusters with 10 clusters populated
# alpha 0.0001 betas 0.25
# Coherence: 0.36322147833020757
# Best coherence: 0.3770413228089349
# In stage 0: transferred 711 clusters with 10 clusters populated
# In stage 1: transferred 454 clusters with 10 clusters populated
# In stage 2: transferred 321 clusters with 10 clusters populated
# In stage 3: transferred 296 clusters with 10 clusters populated
# In stage 4: transferred 260 clusters with 10 clusters populated
# In stage 5: transferred 252 clusters with 10 clusters populated
# In stage 6: transferred 255 clusters with 10 clusters populated
# In stage 7: transferred 238 clusters with 10 clusters populated
# In stage 8: transferred 242 clusters with 10 clusters populated
# In stage 9: transferred 234 clusters with 10 clusters populated
# In stage 10: transferred 232 clusters with 10 clusters populated
# In stage 11: transferred 230 clusters with 10 clusters populated
# In stage 12: transferred 221 clusters with 10 clusters populated
# In stage 13: transferred 211 clusters with 10 clusters populated
# In stage 14: transferred 229 clusters with 10 clusters populated
# alpha 0.0001 betas 0.25
# Coherence: 0.34245058836900943
# Best coherence: 0.3770413228089349
# In stage 0: transferred 682 clusters with 10 clusters populated
# In stage 1: transferred 405 clusters with 10 clusters populated
# In stage 2: transferred 322 clusters with 10 clusters populated
# In stage 3: transferred 298 clusters with 10 clusters populated
# In stage 4: transferred 269 clusters with 10 clusters populated
# In stage 5: transferred 242 clusters with 10 clusters populated
# In stage 6: transferred 239 clusters with 10 clusters populated
# In stage 7: transferred 244 clusters with 10 clusters populated
# In stage 8: transferred 225 clusters with 10 clusters populated
# In stage 9: transferred 221 clusters with 10 clusters populated
# In stage 10: transferred 211 clusters with 10 clusters populated
# In stage 11: transferred 197 clusters with 10 clusters populated
# In stage 12: transferred 225 clusters with 10 clusters populated
# In stage 13: transferred 220 clusters with 10 clusters populated
# In stage 14: transferred 214 clusters with 10 clusters populated
# In stage 15: transferred 205 clusters with 10 clusters populated
# In stage 16: transferred 226 clusters with 10 clusters populated
# In stage 17: transferred 232 clusters with 10 clusters populated
# In stage 18: transferred 213 clusters with 10 clusters populated
# In stage 19: transferred 212 clusters with 10 clusters populated
# alpha 0.0001 betas 0.25
# Coherence: 0.378597241922582
# Best coherence: 0.378597241922582
# In stage 0: transferred 666 clusters with 10 clusters populated
# In stage 1: transferred 348 clusters with 10 clusters populated
# In stage 2: transferred 258 clusters with 10 clusters populated
# In stage 3: transferred 240 clusters with 10 clusters populated
# In stage 4: transferred 205 clusters with 10 clusters populated
# alpha 0.0005 betas 0.1
# Coherence: 0.333903900149277
# Best coherence: 0.378597241922582
# In stage 0: transferred 682 clusters with 10 clusters populated
# In stage 1: transferred 381 clusters with 10 clusters populated
# In stage 2: transferred 282 clusters with 10 clusters populated
# In stage 3: transferred 236 clusters with 10 clusters populated
# In stage 4: transferred 208 clusters with 10 clusters populated
# In stage 5: transferred 201 clusters with 10 clusters populated
# In stage 6: transferred 173 clusters with 10 clusters populated
# In stage 7: transferred 159 clusters with 10 clusters populated
# In stage 8: transferred 170 clusters with 10 clusters populated
# In stage 9: transferred 171 clusters with 10 clusters populated
# alpha 0.0005 betas 0.1
# Coherence: 0.3547091715657412
# Best coherence: 0.378597241922582
# In stage 0: transferred 668 clusters with 10 clusters populated
# In stage 1: transferred 373 clusters with 10 clusters populated
# In stage 2: transferred 268 clusters with 10 clusters populated
# In stage 3: transferred 226 clusters with 10 clusters populated
# In stage 4: transferred 228 clusters with 10 clusters populated
# In stage 5: transferred 203 clusters with 10 clusters populated
# In stage 6: transferred 216 clusters with 10 clusters populated
# In stage 7: transferred 172 clusters with 10 clusters populated
# In stage 8: transferred 191 clusters with 10 clusters populated
# In stage 9: transferred 178 clusters with 10 clusters populated
# In stage 10: transferred 181 clusters with 10 clusters populated
# In stage 11: transferred 167 clusters with 10 clusters populated
# In stage 12: transferred 184 clusters with 10 clusters populated
# In stage 13: transferred 193 clusters with 10 clusters populated
# In stage 14: transferred 177 clusters with 10 clusters populated
# alpha 0.0005 betas 0.1
# Coherence: 0.3594584905304753
# Best coherence: 0.378597241922582
# In stage 0: transferred 676 clusters with 10 clusters populated
# In stage 1: transferred 360 clusters with 10 clusters populated
# In stage 2: transferred 275 clusters with 10 clusters populated
# In stage 3: transferred 264 clusters with 10 clusters populated
# In stage 4: transferred 238 clusters with 10 clusters populated
# In stage 5: transferred 223 clusters with 10 clusters populated
# In stage 6: transferred 199 clusters with 10 clusters populated
# In stage 7: transferred 191 clusters with 10 clusters populated
# In stage 8: transferred 195 clusters with 10 clusters populated
# In stage 9: transferred 190 clusters with 10 clusters populated
# In stage 10: transferred 162 clusters with 10 clusters populated
# In stage 11: transferred 161 clusters with 10 clusters populated
# In stage 12: transferred 162 clusters with 10 clusters populated
# In stage 13: transferred 137 clusters with 10 clusters populated
# In stage 14: transferred 141 clusters with 10 clusters populated
# In stage 15: transferred 148 clusters with 10 clusters populated
# In stage 16: transferred 153 clusters with 10 clusters populated
# In stage 17: transferred 166 clusters with 10 clusters populated
# In stage 18: transferred 179 clusters with 10 clusters populated
# In stage 19: transferred 161 clusters with 10 clusters populated
# alpha 0.0005 betas 0.1
# Coherence: 0.3288637655068952
# Best coherence: 0.378597241922582
# In stage 0: transferred 683 clusters with 10 clusters populated
# In stage 1: transferred 365 clusters with 10 clusters populated
# In stage 2: transferred 298 clusters with 10 clusters populated
# In stage 3: transferred 248 clusters with 10 clusters populated
# In stage 4: transferred 240 clusters with 10 clusters populated
# alpha 0.0005 betas 0.15
# Coherence: 0.2987975574343241
# Best coherence: 0.378597241922582
# In stage 0: transferred 685 clusters with 10 clusters populated
# In stage 1: transferred 389 clusters with 10 clusters populated
# In stage 2: transferred 304 clusters with 10 clusters populated
# In stage 3: transferred 284 clusters with 10 clusters populated
# In stage 4: transferred 236 clusters with 10 clusters populated
# In stage 5: transferred 217 clusters with 10 clusters populated
# In stage 6: transferred 202 clusters with 10 clusters populated
# In stage 7: transferred 202 clusters with 10 clusters populated
# In stage 8: transferred 186 clusters with 10 clusters populated
# In stage 9: transferred 191 clusters with 10 clusters populated
# alpha 0.0005 betas 0.15
# Coherence: 0.3240992808766363
# Best coherence: 0.378597241922582
# In stage 0: transferred 687 clusters with 10 clusters populated
# In stage 1: transferred 384 clusters with 10 clusters populated
# In stage 2: transferred 286 clusters with 10 clusters populated
# In stage 3: transferred 236 clusters with 10 clusters populated
# In stage 4: transferred 226 clusters with 10 clusters populated
# In stage 5: transferred 221 clusters with 10 clusters populated
# In stage 6: transferred 217 clusters with 10 clusters populated
# In stage 7: transferred 195 clusters with 10 clusters populated
# In stage 8: transferred 198 clusters with 10 clusters populated
# In stage 9: transferred 198 clusters with 10 clusters populated
# In stage 10: transferred 183 clusters with 10 clusters populated
# In stage 11: transferred 175 clusters with 10 clusters populated
# In stage 12: transferred 171 clusters with 10 clusters populated
# In stage 13: transferred 186 clusters with 10 clusters populated
# In stage 14: transferred 171 clusters with 10 clusters populated
# alpha 0.0005 betas 0.15
# Coherence: 0.34745593208038483
# Best coherence: 0.378597241922582
# In stage 0: transferred 706 clusters with 10 clusters populated
# In stage 1: transferred 408 clusters with 10 clusters populated
# In stage 2: transferred 299 clusters with 10 clusters populated
# In stage 3: transferred 276 clusters with 10 clusters populated
# In stage 4: transferred 242 clusters with 10 clusters populated
# In stage 5: transferred 225 clusters with 10 clusters populated
# In stage 6: transferred 192 clusters with 10 clusters populated
# In stage 7: transferred 182 clusters with 10 clusters populated
# In stage 8: transferred 204 clusters with 10 clusters populated
# In stage 9: transferred 183 clusters with 10 clusters populated
# In stage 10: transferred 177 clusters with 10 clusters populated
# In stage 11: transferred 172 clusters with 10 clusters populated
# In stage 12: transferred 176 clusters with 10 clusters populated
# In stage 13: transferred 174 clusters with 10 clusters populated
# In stage 14: transferred 164 clusters with 10 clusters populated
# In stage 15: transferred 174 clusters with 10 clusters populated
# In stage 16: transferred 187 clusters with 10 clusters populated
# In stage 17: transferred 163 clusters with 10 clusters populated
# In stage 18: transferred 170 clusters with 10 clusters populated
# In stage 19: transferred 173 clusters with 10 clusters populated
# alpha 0.0005 betas 0.15
# Coherence: 0.3351884254665794
# Best coherence: 0.378597241922582
# In stage 0: transferred 673 clusters with 10 clusters populated
# In stage 1: transferred 409 clusters with 10 clusters populated
# In stage 2: transferred 339 clusters with 10 clusters populated
# In stage 3: transferred 280 clusters with 10 clusters populated
# In stage 4: transferred 243 clusters with 10 clusters populated
# alpha 0.0005 betas 0.2
# Coherence: 0.3173039796837813
# Best coherence: 0.378597241922582
# In stage 0: transferred 691 clusters with 10 clusters populated
# In stage 1: transferred 416 clusters with 10 clusters populated
# In stage 2: transferred 342 clusters with 10 clusters populated
# In stage 3: transferred 294 clusters with 10 clusters populated
# In stage 4: transferred 265 clusters with 10 clusters populated
# In stage 5: transferred 254 clusters with 10 clusters populated
# In stage 6: transferred 220 clusters with 10 clusters populated
# In stage 7: transferred 220 clusters with 10 clusters populated
# In stage 8: transferred 217 clusters with 10 clusters populated
# In stage 9: transferred 211 clusters with 10 clusters populated
# alpha 0.0005 betas 0.2
# Coherence: 0.3654682982860592
# Best coherence: 0.378597241922582
# In stage 0: transferred 688 clusters with 10 clusters populated
# In stage 1: transferred 419 clusters with 10 clusters populated
# In stage 2: transferred 306 clusters with 10 clusters populated
# In stage 3: transferred 251 clusters with 10 clusters populated
# In stage 4: transferred 224 clusters with 10 clusters populated
# In stage 5: transferred 225 clusters with 10 clusters populated
# In stage 6: transferred 234 clusters with 10 clusters populated
# In stage 7: transferred 232 clusters with 10 clusters populated
# In stage 8: transferred 198 clusters with 10 clusters populated
# In stage 9: transferred 206 clusters with 10 clusters populated
# In stage 10: transferred 210 clusters with 10 clusters populated
# In stage 11: transferred 207 clusters with 10 clusters populated
# In stage 12: transferred 199 clusters with 10 clusters populated
# In stage 13: transferred 212 clusters with 10 clusters populated
# In stage 14: transferred 187 clusters with 10 clusters populated
# alpha 0.0005 betas 0.2
# Coherence: 0.3433547603701189
# Best coherence: 0.378597241922582
# In stage 0: transferred 695 clusters with 10 clusters populated
# In stage 1: transferred 391 clusters with 10 clusters populated
# In stage 2: transferred 326 clusters with 10 clusters populated
# In stage 3: transferred 281 clusters with 10 clusters populated
# In stage 4: transferred 229 clusters with 10 clusters populated
# In stage 5: transferred 219 clusters with 10 clusters populated
# In stage 6: transferred 229 clusters with 10 clusters populated
# In stage 7: transferred 222 clusters with 10 clusters populated
# In stage 8: transferred 218 clusters with 10 clusters populated
# In stage 9: transferred 225 clusters with 10 clusters populated
# In stage 10: transferred 200 clusters with 10 clusters populated
# In stage 11: transferred 195 clusters with 10 clusters populated
# In stage 12: transferred 210 clusters with 10 clusters populated
# In stage 13: transferred 208 clusters with 10 clusters populated
# In stage 14: transferred 189 clusters with 10 clusters populated
# In stage 15: transferred 190 clusters with 10 clusters populated
# In stage 16: transferred 181 clusters with 10 clusters populated
# In stage 17: transferred 173 clusters with 10 clusters populated
# In stage 18: transferred 184 clusters with 10 clusters populated
# In stage 19: transferred 190 clusters with 10 clusters populated
# alpha 0.0005 betas 0.2
# Coherence: 0.3295078825884584
# Best coherence: 0.378597241922582
# In stage 0: transferred 686 clusters with 10 clusters populated
# In stage 1: transferred 410 clusters with 10 clusters populated
# In stage 2: transferred 350 clusters with 10 clusters populated
# In stage 3: transferred 309 clusters with 10 clusters populated
# In stage 4: transferred 284 clusters with 10 clusters populated
# alpha 0.0005 betas 0.25
# Coherence: 0.35218753524186597
# Best coherence: 0.378597241922582
# In stage 0: transferred 707 clusters with 10 clusters populated
# In stage 1: transferred 412 clusters with 10 clusters populated
# In stage 2: transferred 310 clusters with 10 clusters populated
# In stage 3: transferred 279 clusters with 10 clusters populated
# In stage 4: transferred 248 clusters with 10 clusters populated
# In stage 5: transferred 217 clusters with 10 clusters populated
# In stage 6: transferred 228 clusters with 10 clusters populated
# In stage 7: transferred 236 clusters with 10 clusters populated
# In stage 8: transferred 234 clusters with 10 clusters populated
# In stage 9: transferred 222 clusters with 10 clusters populated
# alpha 0.0005 betas 0.25
# Coherence: 0.37454573892583853
# Best coherence: 0.378597241922582
# In stage 0: transferred 716 clusters with 10 clusters populated
# In stage 1: transferred 444 clusters with 10 clusters populated
# In stage 2: transferred 325 clusters with 10 clusters populated
# In stage 3: transferred 275 clusters with 10 clusters populated
# In stage 4: transferred 242 clusters with 10 clusters populated
# In stage 5: transferred 240 clusters with 10 clusters populated
# In stage 6: transferred 261 clusters with 10 clusters populated
# In stage 7: transferred 232 clusters with 10 clusters populated
# In stage 8: transferred 234 clusters with 10 clusters populated
# In stage 9: transferred 200 clusters with 10 clusters populated
# In stage 10: transferred 196 clusters with 10 clusters populated
# In stage 11: transferred 221 clusters with 10 clusters populated
# In stage 12: transferred 206 clusters with 10 clusters populated
# In stage 13: transferred 200 clusters with 10 clusters populated
# In stage 14: transferred 227 clusters with 10 clusters populated
# alpha 0.0005 betas 0.25
# Coherence: 0.3642711478208249
# Best coherence: 0.378597241922582
# In stage 0: transferred 702 clusters with 10 clusters populated
# In stage 1: transferred 428 clusters with 10 clusters populated
# In stage 2: transferred 344 clusters with 10 clusters populated
# In stage 3: transferred 285 clusters with 10 clusters populated
# In stage 4: transferred 290 clusters with 10 clusters populated
# In stage 5: transferred 259 clusters with 10 clusters populated
# In stage 6: transferred 242 clusters with 10 clusters populated
# In stage 7: transferred 236 clusters with 10 clusters populated
# In stage 8: transferred 257 clusters with 10 clusters populated
# In stage 9: transferred 241 clusters with 10 clusters populated
# In stage 10: transferred 249 clusters with 10 clusters populated
# In stage 11: transferred 235 clusters with 10 clusters populated
# In stage 12: transferred 239 clusters with 10 clusters populated
# In stage 13: transferred 220 clusters with 10 clusters populated
# In stage 14: transferred 220 clusters with 10 clusters populated
# In stage 15: transferred 224 clusters with 10 clusters populated
# In stage 16: transferred 224 clusters with 10 clusters populated
# In stage 17: transferred 215 clusters with 10 clusters populated
# In stage 18: transferred 227 clusters with 10 clusters populated
# In stage 19: transferred 214 clusters with 10 clusters populated
# alpha 0.0005 betas 0.25
# Coherence: 0.38172262739670587
# Best coherence: 0.38172262739670587
# In stage 0: transferred 684 clusters with 10 clusters populated
# In stage 1: transferred 368 clusters with 10 clusters populated
# In stage 2: transferred 254 clusters with 10 clusters populated
# In stage 3: transferred 215 clusters with 10 clusters populated
# In stage 4: transferred 205 clusters with 10 clusters populated
# alpha 0.001 betas 0.1
# Coherence: 0.371919832412262
# Best coherence: 0.38172262739670587
# In stage 0: transferred 677 clusters with 10 clusters populated
# In stage 1: transferred 371 clusters with 10 clusters populated
# In stage 2: transferred 259 clusters with 10 clusters populated
# In stage 3: transferred 225 clusters with 10 clusters populated
# In stage 4: transferred 204 clusters with 10 clusters populated
# In stage 5: transferred 194 clusters with 10 clusters populated
# In stage 6: transferred 198 clusters with 10 clusters populated
# In stage 7: transferred 193 clusters with 10 clusters populated
# In stage 8: transferred 175 clusters with 10 clusters populated
# In stage 9: transferred 158 clusters with 10 clusters populated
# alpha 0.001 betas 0.1
# Coherence: 0.32249135478034796
# Best coherence: 0.38172262739670587
# In stage 0: transferred 681 clusters with 10 clusters populated
# In stage 1: transferred 363 clusters with 10 clusters populated
# In stage 2: transferred 258 clusters with 10 clusters populated
# In stage 3: transferred 232 clusters with 10 clusters populated
# In stage 4: transferred 221 clusters with 10 clusters populated
# In stage 5: transferred 207 clusters with 10 clusters populated
# In stage 6: transferred 210 clusters with 10 clusters populated
# In stage 7: transferred 190 clusters with 10 clusters populated
# In stage 8: transferred 172 clusters with 10 clusters populated
# In stage 9: transferred 161 clusters with 10 clusters populated
# In stage 10: transferred 189 clusters with 10 clusters populated
# In stage 11: transferred 169 clusters with 10 clusters populated
# In stage 12: transferred 189 clusters with 10 clusters populated
# In stage 13: transferred 161 clusters with 10 clusters populated
# In stage 14: transferred 170 clusters with 10 clusters populated
# alpha 0.001 betas 0.1
# Coherence: 0.3811926290865085
# Best coherence: 0.38172262739670587
# In stage 0: transferred 674 clusters with 10 clusters populated
# In stage 1: transferred 369 clusters with 10 clusters populated
# In stage 2: transferred 280 clusters with 10 clusters populated
# In stage 3: transferred 247 clusters with 10 clusters populated
# In stage 4: transferred 221 clusters with 10 clusters populated
# In stage 5: transferred 212 clusters with 10 clusters populated
# In stage 6: transferred 200 clusters with 10 clusters populated
# In stage 7: transferred 185 clusters with 10 clusters populated
# In stage 8: transferred 182 clusters with 10 clusters populated
# In stage 9: transferred 172 clusters with 10 clusters populated
# In stage 10: transferred 173 clusters with 10 clusters populated
# In stage 11: transferred 159 clusters with 10 clusters populated
# In stage 12: transferred 158 clusters with 10 clusters populated
# In stage 13: transferred 149 clusters with 10 clusters populated
# In stage 14: transferred 164 clusters with 10 clusters populated
# In stage 15: transferred 180 clusters with 10 clusters populated
# In stage 16: transferred 159 clusters with 10 clusters populated
# In stage 17: transferred 165 clusters with 10 clusters populated
# In stage 18: transferred 149 clusters with 10 clusters populated
# In stage 19: transferred 157 clusters with 10 clusters populated
# alpha 0.001 betas 0.1
# Coherence: 0.3524335571058969
# Best coherence: 0.38172262739670587
# In stage 0: transferred 693 clusters with 10 clusters populated
# In stage 1: transferred 374 clusters with 10 clusters populated
# In stage 2: transferred 282 clusters with 10 clusters populated
# In stage 3: transferred 262 clusters with 10 clusters populated
# In stage 4: transferred 213 clusters with 10 clusters populated
# alpha 0.001 betas 0.15
# Coherence: 0.353004918353048
# Best coherence: 0.38172262739670587
# In stage 0: transferred 685 clusters with 10 clusters populated
# In stage 1: transferred 393 clusters with 10 clusters populated
# In stage 2: transferred 270 clusters with 10 clusters populated
# In stage 3: transferred 251 clusters with 10 clusters populated
# In stage 4: transferred 222 clusters with 10 clusters populated
# In stage 5: transferred 197 clusters with 10 clusters populated
# In stage 6: transferred 204 clusters with 10 clusters populated
# In stage 7: transferred 206 clusters with 10 clusters populated
# In stage 8: transferred 178 clusters with 10 clusters populated
# In stage 9: transferred 182 clusters with 10 clusters populated
# alpha 0.001 betas 0.15
# Coherence: 0.3399528107317364
# Best coherence: 0.38172262739670587
# In stage 0: transferred 682 clusters with 10 clusters populated
# In stage 1: transferred 397 clusters with 10 clusters populated
# In stage 2: transferred 315 clusters with 10 clusters populated
# In stage 3: transferred 272 clusters with 10 clusters populated
# In stage 4: transferred 230 clusters with 10 clusters populated
# In stage 5: transferred 214 clusters with 10 clusters populated
# In stage 6: transferred 227 clusters with 10 clusters populated
# In stage 7: transferred 221 clusters with 10 clusters populated
# In stage 8: transferred 212 clusters with 10 clusters populated
# In stage 9: transferred 209 clusters with 10 clusters populated
# In stage 10: transferred 187 clusters with 10 clusters populated
# In stage 11: transferred 203 clusters with 10 clusters populated
# In stage 12: transferred 194 clusters with 10 clusters populated
# In stage 13: transferred 183 clusters with 10 clusters populated
# In stage 14: transferred 171 clusters with 10 clusters populated
# alpha 0.001 betas 0.15
# Coherence: 0.3608405112628181
# Best coherence: 0.38172262739670587
# In stage 0: transferred 677 clusters with 10 clusters populated
# In stage 1: transferred 375 clusters with 10 clusters populated
# In stage 2: transferred 290 clusters with 10 clusters populated
# In stage 3: transferred 252 clusters with 10 clusters populated
# In stage 4: transferred 254 clusters with 10 clusters populated
# In stage 5: transferred 263 clusters with 10 clusters populated
# In stage 6: transferred 241 clusters with 10 clusters populated
# In stage 7: transferred 243 clusters with 10 clusters populated
# In stage 8: transferred 232 clusters with 10 clusters populated
# In stage 9: transferred 217 clusters with 10 clusters populated
# In stage 10: transferred 197 clusters with 10 clusters populated
# In stage 11: transferred 189 clusters with 10 clusters populated
# In stage 12: transferred 206 clusters with 10 clusters populated
# In stage 13: transferred 200 clusters with 10 clusters populated
# In stage 14: transferred 193 clusters with 10 clusters populated
# In stage 15: transferred 208 clusters with 10 clusters populated
# In stage 16: transferred 241 clusters with 10 clusters populated
# In stage 17: transferred 212 clusters with 10 clusters populated
# In stage 18: transferred 195 clusters with 10 clusters populated
# In stage 19: transferred 190 clusters with 10 clusters populated
# alpha 0.001 betas 0.15
# Coherence: 0.36381374916908354
# Best coherence: 0.38172262739670587
# In stage 0: transferred 692 clusters with 10 clusters populated
# In stage 1: transferred 448 clusters with 10 clusters populated
# In stage 2: transferred 323 clusters with 10 clusters populated
# In stage 3: transferred 312 clusters with 10 clusters populated
# In stage 4: transferred 246 clusters with 10 clusters populated
# alpha 0.001 betas 0.2
# Coherence: 0.33561819950726085
# Best coherence: 0.38172262739670587
# In stage 0: transferred 685 clusters with 10 clusters populated
# In stage 1: transferred 416 clusters with 10 clusters populated
# In stage 2: transferred 337 clusters with 10 clusters populated
# In stage 3: transferred 291 clusters with 10 clusters populated
# In stage 4: transferred 241 clusters with 10 clusters populated
# In stage 5: transferred 215 clusters with 10 clusters populated
# In stage 6: transferred 212 clusters with 10 clusters populated
# In stage 7: transferred 206 clusters with 10 clusters populated
# In stage 8: transferred 229 clusters with 10 clusters populated
# In stage 9: transferred 214 clusters with 10 clusters populated
# alpha 0.001 betas 0.2
# Coherence: 0.3513675346839485
# Best coherence: 0.38172262739670587
# In stage 0: transferred 699 clusters with 10 clusters populated
# In stage 1: transferred 400 clusters with 10 clusters populated
# In stage 2: transferred 328 clusters with 10 clusters populated
# In stage 3: transferred 302 clusters with 10 clusters populated
# In stage 4: transferred 266 clusters with 10 clusters populated
# In stage 5: transferred 241 clusters with 10 clusters populated
# In stage 6: transferred 209 clusters with 10 clusters populated
# In stage 7: transferred 250 clusters with 10 clusters populated
# In stage 8: transferred 242 clusters with 10 clusters populated
# In stage 9: transferred 226 clusters with 10 clusters populated
# In stage 10: transferred 202 clusters with 10 clusters populated
# In stage 11: transferred 211 clusters with 10 clusters populated
# In stage 12: transferred 222 clusters with 10 clusters populated
# In stage 13: transferred 209 clusters with 10 clusters populated
# In stage 14: transferred 200 clusters with 10 clusters populated
# alpha 0.001 betas 0.2
# Coherence: 0.3625670662191631
# Best coherence: 0.38172262739670587
# In stage 0: transferred 678 clusters with 10 clusters populated
# In stage 1: transferred 420 clusters with 10 clusters populated
# In stage 2: transferred 315 clusters with 10 clusters populated
# In stage 3: transferred 300 clusters with 10 clusters populated
# In stage 4: transferred 236 clusters with 10 clusters populated
# In stage 5: transferred 259 clusters with 10 clusters populated
# In stage 6: transferred 249 clusters with 10 clusters populated
# In stage 7: transferred 227 clusters with 10 clusters populated
# In stage 8: transferred 237 clusters with 10 clusters populated
# In stage 9: transferred 217 clusters with 10 clusters populated
# In stage 10: transferred 201 clusters with 10 clusters populated
# In stage 11: transferred 200 clusters with 10 clusters populated
# In stage 12: transferred 201 clusters with 10 clusters populated
# In stage 13: transferred 202 clusters with 10 clusters populated
# In stage 14: transferred 213 clusters with 10 clusters populated
# In stage 15: transferred 207 clusters with 10 clusters populated
# In stage 16: transferred 196 clusters with 10 clusters populated
# In stage 17: transferred 202 clusters with 10 clusters populated
# In stage 18: transferred 201 clusters with 10 clusters populated
# In stage 19: transferred 206 clusters with 10 clusters populated
# alpha 0.001 betas 0.2
# Coherence: 0.3698640556876115
# Best coherence: 0.38172262739670587
# In stage 0: transferred 682 clusters with 10 clusters populated
# In stage 1: transferred 391 clusters with 10 clusters populated
# In stage 2: transferred 333 clusters with 10 clusters populated
# In stage 3: transferred 322 clusters with 10 clusters populated
# In stage 4: transferred 288 clusters with 10 clusters populated
# alpha 0.001 betas 0.25
# Coherence: 0.3463635780077402
# Best coherence: 0.38172262739670587
# In stage 0: transferred 674 clusters with 10 clusters populated
# In stage 1: transferred 402 clusters with 10 clusters populated
# In stage 2: transferred 323 clusters with 10 clusters populated
# In stage 3: transferred 278 clusters with 10 clusters populated
# In stage 4: transferred 257 clusters with 10 clusters populated
# In stage 5: transferred 260 clusters with 10 clusters populated
# In stage 6: transferred 236 clusters with 10 clusters populated
# In stage 7: transferred 247 clusters with 10 clusters populated
# In stage 8: transferred 240 clusters with 10 clusters populated
# In stage 9: transferred 224 clusters with 10 clusters populated
# alpha 0.001 betas 0.25
# Coherence: 0.3694984190935152
# Best coherence: 0.38172262739670587
# In stage 0: transferred 693 clusters with 10 clusters populated
# In stage 1: transferred 418 clusters with 10 clusters populated
# In stage 2: transferred 337 clusters with 10 clusters populated
# In stage 3: transferred 312 clusters with 10 clusters populated
# In stage 4: transferred 284 clusters with 10 clusters populated
# In stage 5: transferred 274 clusters with 10 clusters populated
# In stage 6: transferred 242 clusters with 10 clusters populated
# In stage 7: transferred 240 clusters with 10 clusters populated
# In stage 8: transferred 218 clusters with 10 clusters populated
# In stage 9: transferred 228 clusters with 10 clusters populated
# In stage 10: transferred 224 clusters with 10 clusters populated
# In stage 11: transferred 228 clusters with 10 clusters populated
# In stage 12: transferred 235 clusters with 10 clusters populated
# In stage 13: transferred 216 clusters with 10 clusters populated
# In stage 14: transferred 224 clusters with 10 clusters populated
# alpha 0.001 betas 0.25
# Coherence: 0.3867825560162541
# Best coherence: 0.3867825560162541
# In stage 0: transferred 705 clusters with 10 clusters populated
# In stage 1: transferred 458 clusters with 10 clusters populated
# In stage 2: transferred 334 clusters with 10 clusters populated
# In stage 3: transferred 248 clusters with 10 clusters populated
# In stage 4: transferred 250 clusters with 10 clusters populated
# In stage 5: transferred 226 clusters with 10 clusters populated
# In stage 6: transferred 232 clusters with 10 clusters populated
# In stage 7: transferred 228 clusters with 10 clusters populated
# In stage 8: transferred 205 clusters with 10 clusters populated
# In stage 9: transferred 204 clusters with 10 clusters populated
# In stage 10: transferred 219 clusters with 10 clusters populated
# In stage 11: transferred 211 clusters with 10 clusters populated
# In stage 12: transferred 214 clusters with 10 clusters populated
# In stage 13: transferred 211 clusters with 10 clusters populated
# In stage 14: transferred 205 clusters with 10 clusters populated
# In stage 15: transferred 220 clusters with 10 clusters populated
# In stage 16: transferred 222 clusters with 10 clusters populated
# In stage 17: transferred 192 clusters with 10 clusters populated
# In stage 18: transferred 214 clusters with 10 clusters populated
# In stage 19: transferred 197 clusters with 10 clusters populated
# alpha 0.001 betas 0.25
# Coherence: 0.3652195239513909
# Best coherence: 0.3867825560162541
# In stage 0: transferred 694 clusters with 10 clusters populated
# In stage 1: transferred 374 clusters with 10 clusters populated
# In stage 2: transferred 275 clusters with 10 clusters populated
# In stage 3: transferred 219 clusters with 10 clusters populated
# In stage 4: transferred 209 clusters with 10 clusters populated
# alpha 0.005 betas 0.1
# Coherence: 0.3193578640969275
# Best coherence: 0.3867825560162541
# In stage 0: transferred 653 clusters with 10 clusters populated
# In stage 1: transferred 350 clusters with 10 clusters populated
# In stage 2: transferred 276 clusters with 10 clusters populated
# In stage 3: transferred 247 clusters with 10 clusters populated
# In stage 4: transferred 231 clusters with 10 clusters populated
# In stage 5: transferred 196 clusters with 10 clusters populated
# In stage 6: transferred 180 clusters with 10 clusters populated
# In stage 7: transferred 189 clusters with 10 clusters populated
# In stage 8: transferred 186 clusters with 10 clusters populated
# In stage 9: transferred 152 clusters with 10 clusters populated
# alpha 0.005 betas 0.1
# Coherence: 0.37088123165886244
# Best coherence: 0.3867825560162541
# In stage 0: transferred 698 clusters with 10 clusters populated
# In stage 1: transferred 387 clusters with 10 clusters populated
# In stage 2: transferred 300 clusters with 10 clusters populated
# In stage 3: transferred 248 clusters with 10 clusters populated
# In stage 4: transferred 204 clusters with 10 clusters populated
# In stage 5: transferred 181 clusters with 10 clusters populated
# In stage 6: transferred 176 clusters with 10 clusters populated
# In stage 7: transferred 177 clusters with 10 clusters populated
# In stage 8: transferred 155 clusters with 10 clusters populated
# In stage 9: transferred 177 clusters with 10 clusters populated
# In stage 10: transferred 164 clusters with 10 clusters populated
# In stage 11: transferred 175 clusters with 10 clusters populated
# In stage 12: transferred 174 clusters with 10 clusters populated
# In stage 13: transferred 172 clusters with 10 clusters populated
# In stage 14: transferred 166 clusters with 10 clusters populated
# alpha 0.005 betas 0.1
# Coherence: 0.32768355148507766
# Best coherence: 0.3867825560162541
# In stage 0: transferred 684 clusters with 10 clusters populated
# In stage 1: transferred 374 clusters with 10 clusters populated
# In stage 2: transferred 270 clusters with 10 clusters populated
# In stage 3: transferred 235 clusters with 10 clusters populated
# In stage 4: transferred 184 clusters with 10 clusters populated
# In stage 5: transferred 188 clusters with 10 clusters populated
# In stage 6: transferred 163 clusters with 10 clusters populated
# In stage 7: transferred 204 clusters with 10 clusters populated
# In stage 8: transferred 181 clusters with 10 clusters populated
# In stage 9: transferred 195 clusters with 10 clusters populated
# In stage 10: transferred 177 clusters with 10 clusters populated
# In stage 11: transferred 171 clusters with 10 clusters populated
# In stage 12: transferred 172 clusters with 10 clusters populated
# In stage 13: transferred 172 clusters with 10 clusters populated
# In stage 14: transferred 170 clusters with 10 clusters populated
# In stage 15: transferred 162 clusters with 10 clusters populated
# In stage 16: transferred 154 clusters with 10 clusters populated
# In stage 17: transferred 164 clusters with 10 clusters populated
# In stage 18: transferred 167 clusters with 10 clusters populated
# In stage 19: transferred 165 clusters with 10 clusters populated
# alpha 0.005 betas 0.1
# Coherence: 0.3643866132155592
# Best coherence: 0.3867825560162541
# In stage 0: transferred 683 clusters with 10 clusters populated
# In stage 1: transferred 382 clusters with 10 clusters populated
# In stage 2: transferred 293 clusters with 10 clusters populated
# In stage 3: transferred 274 clusters with 10 clusters populated
# In stage 4: transferred 232 clusters with 10 clusters populated
# alpha 0.005 betas 0.15
# Coherence: 0.33696500430027937
# Best coherence: 0.3867825560162541
# In stage 0: transferred 689 clusters with 10 clusters populated
# In stage 1: transferred 393 clusters with 10 clusters populated
# In stage 2: transferred 286 clusters with 10 clusters populated
# In stage 3: transferred 233 clusters with 10 clusters populated
# In stage 4: transferred 218 clusters with 10 clusters populated
# In stage 5: transferred 221 clusters with 10 clusters populated
# In stage 6: transferred 192 clusters with 10 clusters populated
# In stage 7: transferred 195 clusters with 10 clusters populated
# In stage 8: transferred 199 clusters with 10 clusters populated
# In stage 9: transferred 208 clusters with 10 clusters populated
# alpha 0.005 betas 0.15
# Coherence: 0.35270673446149187
# Best coherence: 0.3867825560162541
# In stage 0: transferred 693 clusters with 10 clusters populated
# In stage 1: transferred 393 clusters with 10 clusters populated
# In stage 2: transferred 304 clusters with 10 clusters populated
# In stage 3: transferred 250 clusters with 10 clusters populated
# In stage 4: transferred 240 clusters with 10 clusters populated
# In stage 5: transferred 207 clusters with 10 clusters populated
# In stage 6: transferred 212 clusters with 10 clusters populated
# In stage 7: transferred 214 clusters with 10 clusters populated
# In stage 8: transferred 184 clusters with 10 clusters populated
# In stage 9: transferred 194 clusters with 10 clusters populated
# In stage 10: transferred 175 clusters with 10 clusters populated
# In stage 11: transferred 206 clusters with 10 clusters populated
# In stage 12: transferred 195 clusters with 10 clusters populated
# In stage 13: transferred 211 clusters with 10 clusters populated
# In stage 14: transferred 180 clusters with 10 clusters populated
# alpha 0.005 betas 0.15
# Coherence: 0.3375098091305211
# Best coherence: 0.3867825560162541
# In stage 0: transferred 696 clusters with 10 clusters populated
# In stage 1: transferred 359 clusters with 10 clusters populated
# In stage 2: transferred 277 clusters with 10 clusters populated
# In stage 3: transferred 257 clusters with 10 clusters populated
# In stage 4: transferred 231 clusters with 10 clusters populated
# In stage 5: transferred 213 clusters with 10 clusters populated
# In stage 6: transferred 215 clusters with 10 clusters populated
# In stage 7: transferred 201 clusters with 10 clusters populated
# In stage 8: transferred 213 clusters with 10 clusters populated
# In stage 9: transferred 199 clusters with 10 clusters populated
# In stage 10: transferred 194 clusters with 10 clusters populated
# In stage 11: transferred 183 clusters with 10 clusters populated
# In stage 12: transferred 191 clusters with 10 clusters populated
# In stage 13: transferred 196 clusters with 10 clusters populated
# In stage 14: transferred 187 clusters with 10 clusters populated
# In stage 15: transferred 190 clusters with 10 clusters populated
# In stage 16: transferred 183 clusters with 10 clusters populated
# In stage 17: transferred 187 clusters with 10 clusters populated
# In stage 18: transferred 168 clusters with 10 clusters populated
# In stage 19: transferred 186 clusters with 10 clusters populated
# alpha 0.005 betas 0.15
# Coherence: 0.36045654689679807
# Best coherence: 0.3867825560162541
# In stage 0: transferred 682 clusters with 10 clusters populated
# In stage 1: transferred 396 clusters with 10 clusters populated
# In stage 2: transferred 323 clusters with 10 clusters populated
# In stage 3: transferred 287 clusters with 10 clusters populated
# In stage 4: transferred 257 clusters with 10 clusters populated
# alpha 0.005 betas 0.2
# Coherence: 0.35155455808239905
# Best coherence: 0.3867825560162541
# In stage 0: transferred 692 clusters with 10 clusters populated
# In stage 1: transferred 393 clusters with 10 clusters populated
# In stage 2: transferred 318 clusters with 10 clusters populated
# In stage 3: transferred 303 clusters with 10 clusters populated
# In stage 4: transferred 273 clusters with 10 clusters populated
# In stage 5: transferred 254 clusters with 10 clusters populated
# In stage 6: transferred 250 clusters with 10 clusters populated
# In stage 7: transferred 217 clusters with 10 clusters populated
# In stage 8: transferred 225 clusters with 10 clusters populated
# In stage 9: transferred 225 clusters with 10 clusters populated
# alpha 0.005 betas 0.2
# Coherence: 0.32733004755860207
# Best coherence: 0.3867825560162541
# In stage 0: transferred 689 clusters with 10 clusters populated
# In stage 1: transferred 394 clusters with 10 clusters populated
# In stage 2: transferred 319 clusters with 10 clusters populated
# In stage 3: transferred 297 clusters with 10 clusters populated
# In stage 4: transferred 250 clusters with 10 clusters populated
# In stage 5: transferred 229 clusters with 10 clusters populated
# In stage 6: transferred 209 clusters with 10 clusters populated
# In stage 7: transferred 218 clusters with 10 clusters populated
# In stage 8: transferred 213 clusters with 10 clusters populated
# In stage 9: transferred 201 clusters with 10 clusters populated
# In stage 10: transferred 208 clusters with 10 clusters populated
# In stage 11: transferred 191 clusters with 10 clusters populated
# In stage 12: transferred 209 clusters with 10 clusters populated
# In stage 13: transferred 197 clusters with 10 clusters populated
# In stage 14: transferred 180 clusters with 10 clusters populated
# alpha 0.005 betas 0.2
# Coherence: 0.3692733281084285
# Best coherence: 0.3867825560162541
# In stage 0: transferred 683 clusters with 10 clusters populated
# In stage 1: transferred 411 clusters with 10 clusters populated
# In stage 2: transferred 314 clusters with 10 clusters populated
# In stage 3: transferred 275 clusters with 10 clusters populated
# In stage 4: transferred 260 clusters with 10 clusters populated
# In stage 5: transferred 256 clusters with 10 clusters populated
# In stage 6: transferred 237 clusters with 10 clusters populated
# In stage 7: transferred 226 clusters with 10 clusters populated
# In stage 8: transferred 217 clusters with 10 clusters populated
# In stage 9: transferred 213 clusters with 10 clusters populated
# In stage 10: transferred 212 clusters with 10 clusters populated
# In stage 11: transferred 208 clusters with 10 clusters populated
# In stage 12: transferred 196 clusters with 10 clusters populated
# In stage 13: transferred 220 clusters with 10 clusters populated
# In stage 14: transferred 208 clusters with 10 clusters populated
# In stage 15: transferred 216 clusters with 10 clusters populated
# In stage 16: transferred 209 clusters with 10 clusters populated
# In stage 17: transferred 204 clusters with 10 clusters populated
# In stage 18: transferred 211 clusters with 10 clusters populated
# In stage 19: transferred 194 clusters with 10 clusters populated
# alpha 0.005 betas 0.2
# Coherence: 0.372335497263027
# Best coherence: 0.3867825560162541
# In stage 0: transferred 701 clusters with 10 clusters populated
# In stage 1: transferred 441 clusters with 10 clusters populated
# In stage 2: transferred 344 clusters with 10 clusters populated
# In stage 3: transferred 310 clusters with 10 clusters populated
# In stage 4: transferred 253 clusters with 10 clusters populated
# alpha 0.005 betas 0.25
# Coherence: 0.38571185988681916
# Best coherence: 0.3867825560162541
# In stage 0: transferred 692 clusters with 10 clusters populated
# In stage 1: transferred 413 clusters with 10 clusters populated
# In stage 2: transferred 324 clusters with 10 clusters populated
# In stage 3: transferred 265 clusters with 10 clusters populated
# In stage 4: transferred 255 clusters with 10 clusters populated
# In stage 5: transferred 233 clusters with 10 clusters populated
# In stage 6: transferred 207 clusters with 10 clusters populated
# In stage 7: transferred 222 clusters with 10 clusters populated
# In stage 8: transferred 216 clusters with 10 clusters populated
# In stage 9: transferred 209 clusters with 10 clusters populated
# alpha 0.005 betas 0.25
# Coherence: 0.3321531516850039
# Best coherence: 0.3867825560162541
# In stage 0: transferred 705 clusters with 10 clusters populated
# In stage 1: transferred 432 clusters with 10 clusters populated
# In stage 2: transferred 371 clusters with 10 clusters populated
# In stage 3: transferred 291 clusters with 10 clusters populated
# In stage 4: transferred 262 clusters with 10 clusters populated
# In stage 5: transferred 256 clusters with 10 clusters populated
# In stage 6: transferred 226 clusters with 10 clusters populated
# In stage 7: transferred 266 clusters with 10 clusters populated
# In stage 8: transferred 245 clusters with 10 clusters populated
# In stage 9: transferred 219 clusters with 10 clusters populated
# In stage 10: transferred 230 clusters with 10 clusters populated
# In stage 11: transferred 224 clusters with 10 clusters populated
# In stage 12: transferred 200 clusters with 10 clusters populated
# In stage 13: transferred 216 clusters with 10 clusters populated
# In stage 14: transferred 243 clusters with 10 clusters populated
# alpha 0.005 betas 0.25
# Coherence: 0.38098021935017995
# Best coherence: 0.3867825560162541
# In stage 0: transferred 696 clusters with 10 clusters populated
# In stage 1: transferred 406 clusters with 10 clusters populated
# In stage 2: transferred 312 clusters with 10 clusters populated
# In stage 3: transferred 278 clusters with 10 clusters populated
# In stage 4: transferred 237 clusters with 10 clusters populated
# In stage 5: transferred 231 clusters with 10 clusters populated
# In stage 6: transferred 244 clusters with 10 clusters populated
# In stage 7: transferred 223 clusters with 10 clusters populated
# In stage 8: transferred 219 clusters with 10 clusters populated
# In stage 9: transferred 213 clusters with 10 clusters populated
# In stage 10: transferred 218 clusters with 10 clusters populated
# In stage 11: transferred 209 clusters with 10 clusters populated
# In stage 12: transferred 214 clusters with 10 clusters populated
# In stage 13: transferred 222 clusters with 10 clusters populated
# In stage 14: transferred 214 clusters with 10 clusters populated
# In stage 15: transferred 201 clusters with 10 clusters populated
# In stage 16: transferred 203 clusters with 10 clusters populated
# In stage 17: transferred 207 clusters with 10 clusters populated
# In stage 18: transferred 206 clusters with 10 clusters populated
# In stage 19: transferred 208 clusters with 10 clusters populated
# alpha 0.005 betas 0.25
# Coherence: 0.32418848360116803
# Best coherence: 0.3867825560162541

# %%
# best model cv coherence
alpha = 0.001
beta = 0.2
iteration = 15
coherence_cv = 0.406

# %%
# best model u_mass coherence
alpha = 0.1
beta = 0.01
iters = 20
coherence_umass = -9.63
