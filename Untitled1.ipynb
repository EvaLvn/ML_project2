# %%
import pandas as pd

# %%
from pre_processing import *

# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/robinjaccard/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('out.csv')
# Out:
# /var/folders/4z/k7wkc9t97453h4tqprj_1j3h0000gn/T/ipykernel_44706/2670480247.py:1: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('out.csv')

# %%
df["source"][7]
# Out:
# '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'

# %%
clean_tweets_after_trad(df['translated'])
# Out:
# 0        koran come ramadan kareem protector koran come...
# 1        fight indian show ugly aggression azerbaijani ...
# 2                                    justice sb sorry lose
# 3        country mother hold government position go lic...
# 4             postponement long march decrease case corona
#                                ...
# 22050                                                 join
# 22051    hello active tiger use platform defend islam p...
# 22052                get tipped like see leave one mv sale
# 22053          wolles hot birthday party part laureen pink
# 22054    skill still top tech skill demand cloud amazon...
# Name: text, Length: 22055, dtype: object

# %%
df['text']
# Out:
# 0          رمضان کریم میں قرآن آیا تھا، شعبان میں محافظ...
# 1          Before the fight Indian was showing ugly agg...
# 2                      Justice sb, sorry you have lost it.
# 3          اسی "country" میں تیری ماں حکومتی عہدے پر مل...
# 4          لانگ مارچ ملتوی ہونے کے بعد ، کیا اب کرونا ک...
#                                ...
# 23076                                         How to join?
# 23077        السلام علیکم! ایسے ایکٹیو ٹائیگرز جو اس پل...
# 23078      I just got tipped! Like what you see? You ca...
# 23079      Wolles hot birthday party - part   by Lauree...
# 23080      These skills are still the “Top   Tech Skill...
# Name: text, Length: 23081, dtype: object

# %%
for i in range(50,100):
    n=i
    print("****************************")
    print(df['translated'][n])
    print(df['text'][n])
    print(aa[n])
# Out:
# ****************************
# We will never leave those who do not leave the oppressed alone #GergerlioğluYalsızDeğildir
# Mazlumları yalnız bırakmayanı biz de asla yalnız bırakmayız  #GergerlioğluYalnızDeğildir
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4z/k7wkc9t97453h4tqprj_1j3h0000gn/T/ipykernel_44706/3470059951.py in <module>
#       4     print(df['translated'][n])
#       5     print(df['text'][n])
# ----> 6     print(aa[n])
#
# NameError: name 'aa' is not defined

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

# %%
aa = clean_tweets_after_trad(df['translated'])

# %%
data_pos = aa
plt.figure(figsize = (10,10))
wc = WordCloud(max_words = 200 , width = 1600 , height = 800,
               collocations=False).generate(" ".join(data_pos))
plt.imshow(wc)
