# %%
import pandas as pd

# %%
from pre_processing import *

# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno 8] nodename nor servname provided, or not
# [nltk_data]     known>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# [nltk_data] Error loading punkt: <urlopen error [Errno 8] nodename nor
# [nltk_data]     servname provided, or not known>

# %%
df = pd.read_csv('translated_string.csv')
# Out:
# /var/folders/4z/k7wkc9t97453h4tqprj_1j3h0000gn/T/ipykernel_81871/2230134779.py:1: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('translated_string.csv')

# %%
clean_text = clean_tweets_after_trad(df.translated)

# %%
df['clean_text'] = clean_text

# %% [markdown]
# ## Display the first 150 tweets to see if any problems

# %%
text = "the dreams of my eyes have become disciples, don't know how this is the end of my desire"

# %%
remove_contractions(text)
# Out:
# 'the dreams of my eyes have become disciples, do not know how this is the end of my desire'

# %%
for i in range(0,150):
    print("############################")
    print(df['text'][i])
    print("****************************")
    print(df['translated'][i])
    print("****************************")
    print(clean_text[i])
    print()
# Out:
# ############################
#   #پیپلزپارٹی_ہٹاو_سندھ_بچاؤ Plants installed in Lyari and Kimari were non-functional, he added. “Water board is also invol…
# ****************************
# #PeoplesParty_Hatav_Sindh_Bachao Plants installed in Lyari and Kimari were non-functional, he added. "Water board is also invol...
# ****************************
#  peoples party hatav sindh bachao plants installed in lyari and kimari were non functional, he added. water board is also invol...
#
# ############################
#   Bugün cuma. Nihayet Erdoğan yıllardır beklenen ‘camide bira içtiler’ görüntülerini yayınlandı. Tarih bir kez daha Erdoğan’ı…
# ****************************
# Today is Friday. Finally, Erdogan released the long-awaited footage of 'they drank beer in the mosque'. History once again condemns Erdogan…
# ****************************
# today is friday. finally, erdogan released the long awaited footage of 'they drank beer in the mosque'. history once again condemns erdogan
#
# ...

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_pos = clean_text
plt.figure(figsize = (10,10))
wc = WordCloud(max_words = 200 , width = 1600 , height = 800,
               collocations=False).generate(" ".join(data_pos))
plt.imshow(wc)

# %%
df['clean_text'] = clean_text

# %%
#df.to_csv("clean_text_with_lemmatization")

# %%
df1 = pd.DataFrame(df)

# %%
df1 = pd.DataFrame(df[df["clean_text"].apply(lambda x: len(x.split())) > 3])

# %%
#df1.to_csv("version_without_stemming")

# %%
df1
# Out:
#                         id                 created_at               id_str  \
# 0      1375379386279493637  2021-03-26 09:29:33+00:00  1375379386279493632
# 1      1375379424028336129  2021-03-26 09:29:42+00:00  1375379424028336128
# 2      1375376341244256257  2021-03-26 09:17:27+00:00  1375376341244256256
# 3      1375380522952654849  2021-03-26 09:34:04+00:00  1375380522952654848
# 4      1375372247578378241  2021-03-26 09:01:11+00:00  1375372247578378240
# ...                    ...                        ...                  ...
# 22350  1364445607524405249  2021-02-24 05:22:37+00:00  1364445607524405248
# 22351  1364452276438331396  2021-02-24 05:49:07+00:00  1364452276438331392
# 22353  1364443451622883329  2021-02-24 05:14:03+00:00  1364443451622883328
# 22354  1364452607796903937  2021-02-24 05:50:26+00:00  1364452607796903936
# 22355  1364444865128456192  2021-02-24 05:19:40+00:00  1364444865128456192
#
#                                                     text  \
# ...
