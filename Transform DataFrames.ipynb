# %%
import os
import pandas as pd
import numpy as np
import json
#need pip install langcodes
# and pip install language_data
from langcodes import *
import matplotlib.pyplot as plt
import pycountry
from helpers import *
import pickle

# %load_ext autoreload
# %autoreload 2

# %%
df_cen = pd.read_csv('data/out_clean.csv')
# Out:
# C:\Users\mathi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_cen.to_csv('data/out_clean.csv.gz', compression="gzip")

# %%
df_cen = pd.read_csv('data/out_clean.csv.gz', compression="gzip")
# Out:
# C:\Users\mathi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_cen = eda_processing(df_cen)
# Out:
# C:\Users\mathi\Documents\EPFL_Master\MA3\ML\ML_project2\helpers.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['possibly_sensitive'] = df.possibly_sensitive.apply(lambda x: x == 1 )

# %%
df_cen.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id', 'created_at', 'id_str', 'text',
#        'source', 'truncated', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'place',
#        'withheld_in_countries', 'retweeted_status', 'is_quote_status',
#        'entities', 'lang', 'timestamp_ms', 'linked', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink',
#        'extended_entities', 'possibly_sensitive', 'extended_tweet',
#        'display_text_range', 'withheld_copyright', 'translated', 'clean',
#        'whcs', 'duplicated', 'language'],
#       dtype='object')

# %%
df_save = df_cen[[]]
# Out:
#        Unnamed: 0  Unnamed: 0.1                   id  \
# 0               0             0  1372119376074309633
# 1               1             1  1372121066403942405
# 2               2             2  1372121234163568644
# 3               3             3  1372122714757021697
# 4               4             4  1372120416261656577
# ...           ...           ...                  ...
# 23076       23076         23076  1359369925039644675
# 23077       23077         23077  1359373091764400128
# 23078       23078         23078  1359379144149262337
# 23079       23079         23079  1359379156711002112
# 23080       23080         23080  1359378493998571522
#
#                       created_at               id_str  \
# 0      2021-03-17 09:35:26+00:00  1372119376074309632
# 1      2021-03-17 09:42:09+00:00  1372121066403942400
# 2      2021-03-17 09:42:49+00:00  1372121234163568640
# 3      2021-03-17 09:48:42+00:00  1372122714757021696
# ...
